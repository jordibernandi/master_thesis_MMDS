# %%
# Dictionary of contractions and informal words
contractions = {
    "ain't": "am not",
    "aren't": "are not",
    "can't": "cannot",
    "can't've": "cannot have",
    "'cause": "because",
    "could've": "could have",
    "couldn't": "could not",
    "couldn't've": "could not have",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hadn't've": "had not have",
    "hasn't": "has not",
    "haven't": "have not",
    "he'd": "he would",
    "he'd've": "he would have",
    "he'll": "he will",
    "he'll've": "he will have",
    "he's": "he is",
    "how'd": "how did",
    "how'd'y": "how do you",
    "how'll": "how will",
    "how's": "how is",
    "i'd": "i would",
    "i'd've": "i would have",
    "i'll": "i will",
    "i'll've": "i will have",
    "i'm": "i am",
    "i've": "i have",
    "isn't": "is not",
    "it'd": "it would",
    "it'd've": "it would have",
    "it'll": "it will",
    "it'll've": "it will have",
    "it's": "it is",
    "let's": "let us",
    "ma'am": "madam",
    "mayn't": "may not",
    "might've": "might have",
    "mightn't": "might not",
    "mightn't've": "might not have",
    "must've": "must have",
    "mustn't": "must not",
    "mustn't've": "must not have",
    "needn't": "need not",
    "needn't've": "need not have",
    "o'clock": "of the clock",
    "oughtn't": "ought not",
    "oughtn't've": "ought not have",
    "shan't": "shall not",
    "sha'n't": "shall not",
    "shan't've": "shall not have",
    "she'd": "she would",
    "she'd've": "she would have",
    "she'll": "she will",
    "she'll've": "she will have",
    "she's": "she is",
    "should've": "should have",
    "shouldn't": "should not",
    "shouldn't've": "should not have",
    "so've": "so have",
    "so's": "so is",
    "that'd": "that would",
    "that'd've": "that would have",
    "that's": "that is",
    "there'd": "there would",
    "there'd've": "there would have",
    "there's": "there is",
    "they'd": "they would",
    "they'd've": "they would have",
    "they'll": "they will",
    "they'll've": "they will have",
    "they're": "they are",
    "they've": "they have",
    "to've": "to have",
    "wasn't": "was not",
    "we'd": "we would",
    "we'd've": "we would have",
    "we'll": "we will",
    "we'll've": "we will have",
    "we're": "we are",
    "we've": "we have",
    "weren't": "were not",
    "what'll": "what will",
    "what'll've": "what will have",
    "what're": "what are",
    "what's": "what is",
    "what've": "what have",
    "when's": "when is",
    "when've": "when have",
    "where'd": "where did",
    "where's": "where is",
    "where've": "where have",
    "who'll": "who will",
    "who'll've": "who will have",
    "who's": "who is",
    "who've": "who have",
    "why's": "why is",
    "why've": "why have",
    "will've": "will have",
    "won't": "will not",
    "won't've": "will not have",
    "would've": "would have",
    "wouldn't": "would not",
    "wouldn't've": "would not have",
    "y'all": "you all",
    "y'all'd": "you all would",
    "y'all'd've": "you all would have",
    "y'all're": "you all are",
    "y'all've": "you all have",
    "you'd": "you would",
    "you'd've": "you would have",
    "you'll": "you will",
    "you'll've": "you will have",
    "you're": "you are",
    "you've": "you have",
    "gonna": "going to",
    "wanna": "want to",
    "gotta": "got to",
    "kinda": "kind of",
    "sorta": "sort of",
    "coulda": "could have",
    "woulda": "would have",
    "shoulda": "should have",
    "mighta": "might have",
    "musta": "must have",
    "oughta": "ought to",
}

# Dictionary for censored words and their uncensored counterparts
censored_words = {
    r'f\*+k|f\*+ing|f\*+': 'fuck',
    r's\*+t|s\*+': 'shit',
    r'b\*+ch|b\*+': 'bitch',
    r'd\*+n|d\*+': 'damn',
    r'a\*+hole|a\*+': 'asshole',
    r'b\*+stard|b\*+': 'bastard',
    r'c\*+t|c\*+': 'cunt',
    r'p\*+ssy|p\*+': 'pussy',
    r'd\*+ck|d\*+': 'dick',
    r'mo\*+erf\*+er|mo\*+': 'motherfucker',
}

# %%
import os
import json
import re
from jiwer import wer
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

def load_json(file_path):
    with open(file_path, 'r', encoding='utf-8-sig') as f:
        return json.load(f)

def extract_transcripts(data):
    transcripts = []
    for transcript in data.get("transcripts", []):
        transcripts.append(transcript.get("text", ""))
    return " ".join(transcripts)

# Function to preprocess text
def preprocess_text(text):
     # Normalize censored words
    for pattern, replacement in censored_words.items():
        text = re.sub(pattern, replacement, text, flags=re.IGNORECASE)

     # Remove Unicode characters that are not ASCII
    text = text.encode('ascii', 'ignore').decode()
        
    # Convert text to lowercase
    text = text.lower()
    
    # Replace contractions using regular expressions
    def replace(match):
        return contractions[match.group(0)]
    
    pattern = re.compile(r'\b(' + '|'.join(contractions.keys()) + r')\b')
    text = pattern.sub(replace, text)

    # Remove info like [music]
    text = re.sub(r'\[.*?\]', '', text).strip()
    
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

def evaluate_asr(manual_transcripts, generated_transcripts):
    manual_transcripts = preprocess_text(manual_transcripts)
    generated_transcripts = preprocess_text(generated_transcripts)
  
    return wer(manual_transcripts, generated_transcripts)

def match_files_and_evaluate(manual_folder, generated_folders):
    manual_files = [f for f in os.listdir(manual_folder) if f.endswith('.json')]
    results = []

    for gen_folder in generated_folders:
        gen_files = [f for f in os.listdir(gen_folder) if f.endswith('.json')]
        model_name = os.path.basename(gen_folder)

        for gen_file in gen_files:
            yt_video_id = load_json(os.path.join(gen_folder, gen_file)).get("yt_video_id", "")
            # print(gen_file + " : " + str(yt_video_id))
            if not yt_video_id:
                continue
            manual_file = next((f for f in manual_files if yt_video_id in load_json(os.path.join(manual_folder, f)).get("yt_video_id", "")), None)
            if manual_file:
                manual_data = load_json(os.path.join(manual_folder, manual_file))
                generated_data = load_json(os.path.join(gen_folder, gen_file))

                manual_transcripts = extract_transcripts(manual_data)
                generated_transcripts = extract_transcripts(generated_data)
                
                wer_score = evaluate_asr(manual_transcripts, generated_transcripts)
                results.append({
                    "model": model_name,
                    "manual_file": manual_file,
                    "generated_file": gen_file,
                    "yt_video_id": yt_video_id,
                    "wer": wer_score
                })

    return results

# %%
# # The JSON data
# data = [{'text': " I've had the story for three years. I've had this interview with Virginia Roberts. We would not put it on the air. First of all, I was told, who's Jeffrey Epstein? No one knows who that is. This is a stupid story. Then the palace found out that we had her whole allegations about Prince Andrew and threatened us a million different ways. We were so afraid we wouldn't be able to interview Kate and Will that also quashed the story.", 'start': 4.275, 'end': 29.565}, {'text': ' And then Alan Dershowitz was also implicated in it because of the planes. She told me everything. She had pictures. She had everything. She was in hiding for 12 years. We convinced her to come out. We convinced her to talk to us. It was unbelievable what we had. Clinton. We had everything.', 'start': 30.077, 'end': 46.681}, {'text': " I tried for three years to get it on to no avail, and now it's all coming out, and it's like these new revelations, and I freaking had all of it. I'm so pissed right now. Every day I get more and more pissed because I'm just like, oh, my God. What we had was unreal. Other women backing it up, hey, yep.", 'start': 48.319, 'end': 69.787}, {'text': " Brad Edwards, the attorney, three years ago, saying, like, there will come a day when we will realize Jeffrey Epstein was the most prolific pedophile this country has ever known. I had it all three years ago. Yes. First of all, I was told, who's Jeffrey Epstein? No one knows who that is.", 'start': 71.169, 'end': 99.309}, {'text': " It was unbelievable what we had. Clinton, everything. Then the palace found out that we had her whole allegations about Prince Andrew and threatened us a million different ways. I've had the story for three years. I've had this interview with Virginia Roberts. We would not put it on the air. That's tape leaked to us by our latest network insider. This brave insider works at ABC News.", 'start': 102.79, 'end': 127.295}, {'text': ' ABC News anchorwoman Amy Robach is talking to her producer on a hot mic. She says she had the Jeffrey Epstein story three years ago and her bosses at ABC News spiked it. And then Alan Dershowitz was also implicated in it because of the planes. She told me everything. She had pictures. She had everything. She was in hiding for 12 years. We convinced her to come out. We convinced her to talk to us. It was unbelievable what we had. Clinton. We had everything.', 'start': 127.927, 'end': 155.316}, {'text': " I tried for three years to get it on to no avail, and now it's all coming out, and it's like these new revelations, and I freaking had all of it. I'm so pissed right now. Every day I get more and more pissed because I'm just like, oh, my God. What we had was unreal.", 'start': 156.937, 'end': 175.913}, {'text': ' Our insider told us this tape was recorded earlier this year in late August, a day or so after this NPR report came out sharply criticizing ABC News for not broadcasting the Roebuck-Giuffre interview years ago. ABC has episodically covered the scandal, yet the interview was never broadcast, and Giuffre says she was never told why. Are there women backing it up? Hey. Yep. Brad Edwards, the attorney, three years ago saying, like, aunt, like,', 'start': 175.913, 'end': 204.036}, {'text': " There will come a day when we will realize Jeffrey Epstein was the most prolific pedophile this country has ever known. I had it all three years ago. But the creepy thing is that we wouldn't make access to all of these high profile people. Well, then I got a little concerned about why I couldn't get on.", 'start': 204.462, 'end': 221.391}, {'text': ' On the leaked insider tape, Amy Robach says she had the Jeffrey Epstein story three years prior, but her exclusive interview was shelved. Robach says in the leaked tape there was a lot of pressure from Buckingham Palace. According to NPR, the famed lawyer Alan Dershowitz also pressured the network to kill the story.', 'start': 221.647, 'end': 240.469}, {'text': " Shortly before the interview was due to air, Harvard emeritus law professor Alan Dershowitz called the network. He was also one of Epstein's lead defense attorneys. We wonder if the story was killed to protect the rich and powerful. It seems few were worried about protecting the women who may have been Jeffrey Epstein's victims. Remember, Epstein was still a free man three years ago. And just to be clear, the interview has still not aired. What is ABC News waiting for, or who are they still protecting?", 'start': 240.776, 'end': 268.268}, {'text': ' She told me everything. She had pictures. She had everything. She was in hiding for 12 years. We convinced her to come out. We convinced her to talk to us. It was unbelievable what we had. Clinton. We had everything. Robach also has no doubt about what happened to Epstein when he finally was arrested and jailed. So do I think he was killed? A hundred percent. Yes, I do. Because he made his whole living blackmailing people.', 'start': 268.814, 'end': 295.538}, {'text': ' Yeah. There were a lot of men in those planes, a lot of men who visited that island, a lot of powerful men who came into that apartment. I knew immediately.', 'start': 300.503, 'end': 322.449}, {'text': " And they made it seem as though he made that suicide attempt two weeks earlier, but his lawyers claimed that he was roughed up by his cellmate around the neck. That was all, like, to plant the seed. And then... That's why I really believe it. Like, really believe it.", 'start': 325.418, 'end': 343.319}, {'text': " The last of the leaked tape has Roebuck talking about alleged Epstein conspirator Ghislaine Maxwell and how she should be very careful. He's got to have left evidence in me, you know, unexplained. Well, Ghislaine Maxwell, who I had all sorts of stuff on her, too. I love it. I'm like, it's so funny to hear everyone say her name. I'm like, oh, my God. Like, I had all that. And everyone's like, who's that? Who cares? I kept getting that. Who cares?", 'start': 347.79, 'end': 376.561}, {'text': " Um, she knows everything. She knows, she knows, she should, she should be careful. Well, she was his, like, she went out and recruited all of these girls. She should watch her back. Because if she goes, I mean, I'd have like security guards all around me.", 'start': 378.217, 'end': 405.06}, {'text': ' The brave insider who leaked this tape to us does not know who at ABC News spiked the story. But someone at ABC does. Our question.', 'start': 406.271, 'end': 416.203}, {'text': " Who killed the Epstein story at ABC News and why? Help us find out. James Goldston is the president of ABC News. What did he know and when did he know it? Here's the landline number for ABC News president Goldston and his Twitter account. If you're an insider at ABC News or any other major media outlet or big tech company and you have seen corruption or bias, contact us at projectveritas.com.", 'start': 416.544, 'end': 445.503}, {'text': ' Be a catalyst for change. Be brave. Do something.', 'start': 445.503, 'end': 452.688}]

# # Concatenating all the text into one paragraph
# paragraph = " ".join(item['text'] for item in data)

# # Printing the concatenated paragraph
# print(paragraph)

# %%
# text1 = "I've had the story for three years. I've had this interview with Virginia Roberts. We would not put it on the air. First of all, I was told, who's Jeffrey Epstein? No one knows who that is. This is a stupid story. Then the palace found out that we had her whole allegations about Prince Andrew and threatened us a million different ways. We were so afraid we wouldn't be able to interview Kate and Will that also quashed the story.  And then Alan Dershowitz was also implicated in it because of the planes. She told me everything. She had pictures. She had everything. She was in hiding for 12 years. We convinced her to come out. We convinced her to talk to us. It was unbelievable what we had. Clinton. We had everything.  I tried for three years to get it on to no avail, and now it's all coming out, and it's like these new revelations, and I freaking had all of it. I'm so pissed right now. Every day I get more and more pissed because I'm just like, oh, my God. What we had was unreal. Other women backing it up, hey, yep.  Brad Edwards, the attorney, three years ago, saying, like, there will come a day when we will realize Jeffrey Epstein was the most prolific pedophile this country has ever known. I had it all three years ago. Yes. First of all, I was told, who's Jeffrey Epstein? No one knows who that is.  It was unbelievable what we had. Clinton, everything. Then the palace found out that we had her whole allegations about Prince Andrew and threatened us a million different ways. I've had the story for three years. I've had this interview with Virginia Roberts. We would not put it on the air. That's tape leaked to us by our latest network insider. This brave insider works at ABC News.  ABC News anchorwoman Amy Robach is talking to her producer on a hot mic. She says she had the Jeffrey Epstein story three years ago and her bosses at ABC News spiked it. And then Alan Dershowitz was also implicated in it because of the planes. She told me everything. She had pictures. She had everything. She was in hiding for 12 years. We convinced her to come out. We convinced her to talk to us. It was unbelievable what we had. Clinton. We had everything.  I tried for three years to get it on to no avail, and now it's all coming out, and it's like these new revelations, and I freaking had all of it. I'm so pissed right now. Every day I get more and more pissed because I'm just like, oh, my God. What we had was unreal.  Our insider told us this tape was recorded earlier this year in late August, a day or so after this NPR report came out sharply criticizing ABC News for not broadcasting the Roebuck-Giuffre interview years ago. ABC has episodically covered the scandal, yet the interview was never broadcast, and Giuffre says she was never told why. Are there women backing it up? Hey. Yep. Brad Edwards, the attorney, three years ago saying, like, aunt, like,  There will come a day when we will realize Jeffrey Epstein was the most prolific pedophile this country has ever known. I had it all three years ago. But the creepy thing is that we wouldn't make access to all of these high profile people. Well, then I got a little concerned about why I couldn't get on.  On the leaked insider tape, Amy Robach says she had the Jeffrey Epstein story three years prior, but her exclusive interview was shelved. Robach says in the leaked tape there was a lot of pressure from Buckingham Palace. According to NPR, the famed lawyer Alan Dershowitz also pressured the network to kill the story.  Shortly before the interview was due to air, Harvard emeritus law professor Alan Dershowitz called the network. He was also one of Epstein's lead defense attorneys. We wonder if the story was killed to protect the rich and powerful. It seems few were worried about protecting the women who may have been Jeffrey Epstein's victims. Remember, Epstein was still a free man three years ago. And just to be clear, the interview has still not aired. What is ABC News waiting for, or who are they still protecting?  She told me everything. She had pictures. She had everything. She was in hiding for 12 years. We convinced her to come out. We convinced her to talk to us. It was unbelievable what we had. Clinton. We had everything. Robach also has no doubt about what happened to Epstein when he finally was arrested and jailed. So do I think he was killed? A hundred percent. Yes, I do. Because he made his whole living blackmailing people.  Yeah. There were a lot of men in those planes, a lot of men who visited that island, a lot of powerful men who came into that apartment. I knew immediately.  And they made it seem as though he made that suicide attempt two weeks earlier, but his lawyers claimed that he was roughed up by his cellmate around the neck. That was all, like, to plant the seed. And then... That's why I really believe it. Like, really believe it.  The last of the leaked tape has Roebuck talking about alleged Epstein conspirator Ghislaine Maxwell and how she should be very careful. He's got to have left evidence in me, you know, unexplained. Well, Ghislaine Maxwell, who I had all sorts of stuff on her, too. I love it. I'm like, it's so funny to hear everyone say her name. I'm like, oh, my God. Like, I had all that. And everyone's like, who's that? Who cares? I kept getting that. Who cares?  Um, she knows everything. She knows, she knows, she should, she should be careful. Well, she was his, like, she went out and recruited all of these girls. She should watch her back. Because if she goes, I mean, I'd have like security guards all around me.  The brave insider who leaked this tape to us does not know who at ABC News spiked the story. But someone at ABC does. Our question.  Who killed the Epstein story at ABC News and why? Help us find out. James Goldston is the president of ABC News. What did he know and when did he know it? Here's the landline number for ABC News president Goldston and his Twitter account. If you're an insider at ABC News or any other major media outlet or big tech company and you have seen corruption or bias, contact us at projectveritas.com.  Be a catalyst for change. Be brave. Do something."
# text2 = "I've had the story for three years. I've had this interview with Virginia Roberts. We would not put it on the air. First of all, I was told, who's Jeffrey Epstein? No one knows who that is. This is a stupid story. Then the palace found out that we had her whole allegations about Prince Andrew and threatened us a million different ways. We were so afraid we wouldn't be able to interview Kate and Will that also quashed the story. And then Alan Dershowitz was also implicated in it because of the planes. She told me everything. She had pictures. She had everything. She was in hiding for 12 years. We convinced her to come out. We convinced her to talk to us. It was unbelievable what we had. Clinton. We had everything. I tried for three years to get it on to no avail, and now it's all coming out, and it's like these new revelations, and I freaking had all of it. I'm so pissed right now. Every day I get more and more pissed because I'm just like, oh, my God. What we had was unreal. Other women backing it up, hey, yep. Brad Edwards, the attorney, three years ago, saying, like, there will come a day when we will realize Jeffrey Epstein was the most prolific pedophile this country has ever known. I had it all three years ago. Yes. First of all, I was told, who's Jeffrey Epstein? No one knows who that is. It was unbelievable what we had. Clinton, everything. Then the palace found out that we had her whole allegations about Prince Andrew and threatened us a million different ways. I've had the story for three years. I've had this interview with Virginia Roberts. We would not put it on the air. That's tape leaked to us by our latest network insider. This brave insider works at ABC News. ABC News anchorwoman Amy Robach is talking to her producer on a hot mic. She says she had the Jeffrey Epstein story three years ago and her bosses at ABC News spiked it. And then Alan Dershowitz was also implicated in it because of the planes. She told me everything. She had pictures. She had everything. She was in hiding for 12 years. We convinced her to come out. We convinced her to talk to us. It was unbelievable what we had. Clinton. We had everything. I tried for three years to get it on to no avail, and now it's all coming out, and it's like these new revelations, and I freaking had all of it. I'm so pissed right now. Every day I get more and more pissed because I'm just like, oh, my God. What we had was unreal. Our insider told us this tape was recorded earlier this year in late August, a day or so after this NPR report came out sharply criticizing ABC News for not broadcasting the Roebuck-Giuffre interview years ago. ABC has episodically covered the scandal, yet the interview was never broadcast, and Giuffre says she was never told why. Are there women backing it up? Hey. Yep. Brad Edwards, the attorney, three years ago saying, like, aunt, like, There will come a day when we will realize Jeffrey Epstein was the most prolific pedophile this country has ever known. I had it all three years ago. But the creepy thing is that we wouldn't make access to all of these high profile people. Well, then I got a little concerned about why I couldn't get on. On the leaked insider tape, Amy Robach says she had the Jeffrey Epstein story three years prior, but her exclusive interview was shelved. Robach says in the leaked tape there was a lot of pressure from Buckingham Palace. According to NPR, the famed lawyer Alan Dershowitz also pressured the network to kill the story. Shortly before the interview was due to air, Harvard emeritus law professor Alan Dershowitz called the network. He was also one of Epstein's lead defense attorneys. We wonder if the story was killed to protect the rich and powerful. It seems few were worried about protecting the women who may have been Jeffrey Epstein's victims. Remember, Epstein was still a free man three years ago. And just to be clear, the interview has still not aired. What is ABC News waiting for, or who are they still protecting? She told me everything. She had pictures. She had everything. She was in hiding for 12 years. We convinced her to come out. We convinced her to talk to us. It was unbelievable what we had. Clinton. We had everything. Robach also has no doubt about what happened to Epstein when he finally was arrested and jailed. So do I think he was killed? A hundred percent. Yes, I do. Because he made his whole living blackmailing people. Yeah. There were a lot of men in those planes, a lot of men who visited that island, a lot of powerful men who came into that apartment. I knew immediately. And they made it seem as though he made that suicide attempt two weeks earlier, but his lawyers claimed that he was roughed up by his cellmate around the neck. That was all, like, to plant the seed. And then... That's why I really believe it. Like, really believe it. The last of the leaked tape has Roebuck talking about alleged Epstein conspirator Ghislaine Maxwell and how she should be very careful. He's got to have left evidence in me, you know, unexplained. Well, Ghislaine Maxwell, who I had all sorts of stuff on her, too. I love it. I'm like, it's so funny to hear everyone say her name. I'm like, oh, my God. Like, I had all that. And everyone's like, who's that? Who cares? I kept getting that. Who cares? Um, she knows everything. She knows, she knows, she should, she should be careful. Well, she was his, like, she went out and recruited all of these girls. She should watch her back. Because if she goes, I mean, I'd have like security guards all around me. The brave insider who leaked this tape to us does not know who at ABC News spiked the story. But someone at ABC does. Our question. Who killed the Epstein story at ABC News and why? Help us find out. James Goldston is the president of ABC News. What did he know and when did he know it? Here's the landline number for ABC News president Goldston and his Twitter account. If you're an insider at ABC News or any other major media outlet or big tech company and you have seen corruption or bias, contact us at projectveritas.com. Be a catalyst for change. Be brave. Do something."

# evaluate_asr(text1, text2)

# %%
manual_folder = 'test_data'
generated_folders = [
    'Whisper-Pyannote_large-v3',
    'Whisper-Nemo_base.en',
    'Whisper-Nemo_base',
    'Whisper-Nemo_tiny.en',
    'Whisper-Nemo_tiny',
    'Whisper-Nemo_small.en',
    'Whisper-Nemo_small',
    'Whisper-Nemo_medium.en',
    'Whisper-Nemo_medium',
    'Whisper-Nemo_large',
    'Whisper-Nemo_large--no-stem',
    'Whisper-Nemo_large-v1',
    'Whisper-Nemo_large-v2',
    'Whisper-Nemo_large-v3',
    'Whisper-Nemo_large-v3--no-stem',
    'Whisper-Only'
    # Add more generated folders as needed
]

results = match_files_and_evaluate(manual_folder, generated_folders)

# %%
results_df = pd.DataFrame(results)
results_df.sort_values(by='manual_file')
# Out:
#                               model                               manual_file  \
# 48             Whisper-Nemo_base.en                 after_covid_ANTI_SJW.json
# 216          Whisper-Nemo_medium.en                 after_covid_ANTI_SJW.json
# 244             Whisper-Nemo_medium                 after_covid_ANTI_SJW.json
# 160           Whisper-Nemo_small.en                 after_covid_ANTI_SJW.json
# 272              Whisper-Nemo_large                 after_covid_ANTI_SJW.json
# 300     Whisper-Nemo_large--no-stem                 after_covid_ANTI_SJW.json
# 132               Whisper-Nemo_tiny                 after_covid_ANTI_SJW.json
# 20        Whisper-Pyannote_large-v3                 after_covid_ANTI_SJW.json
# 328           Whisper-Nemo_large-v1                 after_covid_ANTI_SJW.json
# 356           Whisper-Nemo_large-v2                 after_covid_ANTI_SJW.json
# 104            Whisper-Nemo_tiny.en                 after_covid_ANTI_SJW.json
# 384           Whisper-Nemo_large-v3                 after_covid_ANTI_SJW.json
# 412  Whisper-Nemo_large-v3--no-stem                 after_covid_ANTI_SJW.json
# 76                Whisper-Nemo_base                 after_covid_ANTI_SJW.json
# 440                    Whisper-Only                 after_covid_ANTI_SJW.json
# 188              Whisper-Nemo_small                 after_covid_ANTI_SJW.json
# 139               Whisper-Nemo_tiny              after_covid_ANTI_THEIST.json
# 83                Whisper-Nemo_base              after_covid_ANTI_THEIST.json
# 111            Whisper-Nemo_tiny.en              after_covid_ANTI_THEIST.json
# 223          Whisper-Nemo_medium.en              after_covid_ANTI_THEIST.json
# 195              Whisper-Nemo_small              after_covid_ANTI_THEIST.json
# 55             Whisper-Nemo_base.en              after_covid_ANTI_THEIST.json
# 279              Whisper-Nemo_large              after_covid_ANTI_THEIST.json
# 307     Whisper-Nemo_large--no-stem              after_covid_ANTI_THEIST.json
# 335           Whisper-Nemo_large-v1              after_covid_ANTI_THEIST.json
# 363           Whisper-Nemo_large-v2              after_covid_ANTI_THEIST.json
# 391           Whisper-Nemo_large-v3              after_covid_ANTI_THEIST.json
# 419  Whisper-Nemo_large-v3--no-stem              after_covid_ANTI_THEIST.json
# 167           Whisper-Nemo_small.en              after_covid_ANTI_THEIST.json
# 251             Whisper-Nemo_medium              after_covid_ANTI_THEIST.json
# 447                    Whisper-Only              after_covid_ANTI_THEIST.json
# 27        Whisper-Pyannote_large-v3              after_covid_ANTI_THEIST.json
# 348           Whisper-Nemo_large-v2                    after_covid_BLACK.json
# 376           Whisper-Nemo_large-v3                    after_covid_BLACK.json
# 320           Whisper-Nemo_large-v1                    after_covid_BLACK.json
# 96             Whisper-Nemo_tiny.en                    after_covid_BLACK.json
# 124               Whisper-Nemo_tiny                    after_covid_BLACK.json
# 404  Whisper-Nemo_large-v3--no-stem                    after_covid_BLACK.json
# 292     Whisper-Nemo_large--no-stem                    after_covid_BLACK.json
# 40             Whisper-Nemo_base.en                    after_covid_BLACK.json
# 180              Whisper-Nemo_small                    after_covid_BLACK.json
# 208          Whisper-Nemo_medium.en                    after_covid_BLACK.json
# 236             Whisper-Nemo_medium                    after_covid_BLACK.json
# 264              Whisper-Nemo_large                    after_covid_BLACK.json
# 68                Whisper-Nemo_base                    after_covid_BLACK.json
# 432                    Whisper-Only                    after_covid_BLACK.json
# 152           Whisper-Nemo_small.en                    after_covid_BLACK.json
# 12        Whisper-Pyannote_large-v3                    after_covid_BLACK.json
# 334           Whisper-Nemo_large-v1               after_covid_CONSPIRACY.json
# 222          Whisper-Nemo_medium.en               after_covid_CONSPIRACY.json
# 194              Whisper-Nemo_small               after_covid_CONSPIRACY.json
# 26        Whisper-Pyannote_large-v3               after_covid_CONSPIRACY.json
# 138               Whisper-Nemo_tiny               after_covid_CONSPIRACY.json
# 446                    Whisper-Only               after_covid_CONSPIRACY.json
# 362           Whisper-Nemo_large-v2               after_covid_CONSPIRACY.json
# 82                Whisper-Nemo_base               after_covid_CONSPIRACY.json
# 250             Whisper-Nemo_medium               after_covid_CONSPIRACY.json
# 54             Whisper-Nemo_base.en               after_covid_CONSPIRACY.json
# 166           Whisper-Nemo_small.en               after_covid_CONSPIRACY.json
# 390           Whisper-Nemo_large-v3               after_covid_CONSPIRACY.json
# 306     Whisper-Nemo_large--no-stem               after_covid_CONSPIRACY.json
# 418  Whisper-Nemo_large-v3--no-stem               after_covid_CONSPIRACY.json
# 278              Whisper-Nemo_large               after_covid_CONSPIRACY.json
# 110            Whisper-Nemo_tiny.en               after_covid_CONSPIRACY.json
# 10        Whisper-Pyannote_large-v3                     after_covid_LGBT.json
# 290     Whisper-Nemo_large--no-stem                     after_covid_LGBT.json
# 234             Whisper-Nemo_medium                     after_covid_LGBT.json
# 122               Whisper-Nemo_tiny                     after_covid_LGBT.json
# 206          Whisper-Nemo_medium.en                     after_covid_LGBT.json
# 262              Whisper-Nemo_large                     after_covid_LGBT.json
# 318           Whisper-Nemo_large-v1                     after_covid_LGBT.json
# 94             Whisper-Nemo_tiny.en                     after_covid_LGBT.json
# 346           Whisper-Nemo_large-v2                     after_covid_LGBT.json
# 150           Whisper-Nemo_small.en                     after_covid_LGBT.json
# 374           Whisper-Nemo_large-v3                     after_covid_LGBT.json
# 402  Whisper-Nemo_large-v3--no-stem                     after_covid_LGBT.json
# 38             Whisper-Nemo_base.en                     after_covid_LGBT.json
# 66                Whisper-Nemo_base                     after_covid_LGBT.json
# 178              Whisper-Nemo_small                     after_covid_LGBT.json
# 430                    Whisper-Only                     after_covid_LGBT.json
# 36             Whisper-Nemo_base.en              after_covid_LIBERTARIAN.json
# 428                    Whisper-Only              after_covid_LIBERTARIAN.json
# 232             Whisper-Nemo_medium              after_covid_LIBERTARIAN.json
# 288     Whisper-Nemo_large--no-stem              after_covid_LIBERTARIAN.json
# 148           Whisper-Nemo_small.en              after_covid_LIBERTARIAN.json
# 260              Whisper-Nemo_large              after_covid_LIBERTARIAN.json
# 120               Whisper-Nemo_tiny              after_covid_LIBERTARIAN.json
# 400  Whisper-Nemo_large-v3--no-stem              after_covid_LIBERTARIAN.json
# 204          Whisper-Nemo_medium.en              after_covid_LIBERTARIAN.json
# 176              Whisper-Nemo_small              after_covid_LIBERTARIAN.json
# 92             Whisper-Nemo_tiny.en              after_covid_LIBERTARIAN.json
# 64                Whisper-Nemo_base              after_covid_LIBERTARIAN.json
# 344           Whisper-Nemo_large-v2              after_covid_LIBERTARIAN.json
# 316           Whisper-Nemo_large-v1              after_covid_LIBERTARIAN.json
# 372           Whisper-Nemo_large-v3              after_covid_LIBERTARIAN.json
# 8         Whisper-Pyannote_large-v3              after_covid_LIBERTARIAN.json
# 259              Whisper-Nemo_large                      after_covid_MRA.json
# 343           Whisper-Nemo_large-v2                      after_covid_MRA.json
# 35             Whisper-Nemo_base.en                      after_covid_MRA.json
# 7         Whisper-Pyannote_large-v3                      after_covid_MRA.json
# 203          Whisper-Nemo_medium.en                      after_covid_MRA.json
# 427                    Whisper-Only                      after_covid_MRA.json
# 231             Whisper-Nemo_medium                      after_covid_MRA.json
# 91             Whisper-Nemo_tiny.en                      after_covid_MRA.json
# 63                Whisper-Nemo_base                      after_covid_MRA.json
# 371           Whisper-Nemo_large-v3                      after_covid_MRA.json
# 147           Whisper-Nemo_small.en                      after_covid_MRA.json
# 399  Whisper-Nemo_large-v3--no-stem                      after_covid_MRA.json
# 175              Whisper-Nemo_small                      after_covid_MRA.json
# 315           Whisper-Nemo_large-v1                      after_covid_MRA.json
# 287     Whisper-Nemo_large--no-stem                      after_covid_MRA.json
# 119               Whisper-Nemo_tiny                      after_covid_MRA.json
# 196          Whisper-Nemo_medium.en            after_covid_PARTISAN_LEFT.json
# 140           Whisper-Nemo_small.en            after_covid_PARTISAN_LEFT.json
# 168              Whisper-Nemo_small            after_covid_PARTISAN_LEFT.json
# 224             Whisper-Nemo_medium            after_covid_PARTISAN_LEFT.json
# 0         Whisper-Pyannote_large-v3            after_covid_PARTISAN_LEFT.json
# 364           Whisper-Nemo_large-v3            after_covid_PARTISAN_LEFT.json
# 336           Whisper-Nemo_large-v2            after_covid_PARTISAN_LEFT.json
# 56                Whisper-Nemo_base            after_covid_PARTISAN_LEFT.json
# 28             Whisper-Nemo_base.en            after_covid_PARTISAN_LEFT.json
# 84             Whisper-Nemo_tiny.en            after_covid_PARTISAN_LEFT.json
# 392  Whisper-Nemo_large-v3--no-stem            after_covid_PARTISAN_LEFT.json
# 308           Whisper-Nemo_large-v1            after_covid_PARTISAN_LEFT.json
# 252              Whisper-Nemo_large            after_covid_PARTISAN_LEFT.json
# 420                    Whisper-Only            after_covid_PARTISAN_LEFT.json
# 280     Whisper-Nemo_large--no-stem            after_covid_PARTISAN_LEFT.json
# 112               Whisper-Nemo_tiny            after_covid_PARTISAN_LEFT.json
# 369           Whisper-Nemo_large-v3           after_covid_PARTISAN_RIGHT.json
# 5         Whisper-Pyannote_large-v3           after_covid_PARTISAN_RIGHT.json
# 173              Whisper-Nemo_small           after_covid_PARTISAN_RIGHT.json
# 425                    Whisper-Only           after_covid_PARTISAN_RIGHT.json
# 33             Whisper-Nemo_base.en           after_covid_PARTISAN_RIGHT.json
# 61                Whisper-Nemo_base           after_covid_PARTISAN_RIGHT.json
# 397  Whisper-Nemo_large-v3--no-stem           after_covid_PARTISAN_RIGHT.json
# 145           Whisper-Nemo_small.en           after_covid_PARTISAN_RIGHT.json
# 117               Whisper-Nemo_tiny           after_covid_PARTISAN_RIGHT.json
# 313           Whisper-Nemo_large-v1           after_covid_PARTISAN_RIGHT.json
# 341           Whisper-Nemo_large-v2           after_covid_PARTISAN_RIGHT.json
# 257              Whisper-Nemo_large           after_covid_PARTISAN_RIGHT.json
# 89             Whisper-Nemo_tiny.en           after_covid_PARTISAN_RIGHT.json
# 229             Whisper-Nemo_medium           after_covid_PARTISAN_RIGHT.json
# 201          Whisper-Nemo_medium.en           after_covid_PARTISAN_RIGHT.json
# 285     Whisper-Nemo_large--no-stem           after_covid_PARTISAN_RIGHT.json
# 435                    Whisper-Only                    after_covid_QANON.json
# 15        Whisper-Pyannote_large-v3                    after_covid_QANON.json
# 267              Whisper-Nemo_large                    after_covid_QANON.json
# 351           Whisper-Nemo_large-v2                    after_covid_QANON.json
# 295     Whisper-Nemo_large--no-stem                    after_covid_QANON.json
# 323           Whisper-Nemo_large-v1                    after_covid_QANON.json
# 183              Whisper-Nemo_small                    after_covid_QANON.json
# 211          Whisper-Nemo_medium.en                    after_covid_QANON.json
# 379           Whisper-Nemo_large-v3                    after_covid_QANON.json
# 407  Whisper-Nemo_large-v3--no-stem                    after_covid_QANON.json
# 155           Whisper-Nemo_small.en                    after_covid_QANON.json
# 239             Whisper-Nemo_medium                    after_covid_QANON.json
# 71                Whisper-Nemo_base                    after_covid_QANON.json
# 43             Whisper-Nemo_base.en                    after_covid_QANON.json
# 99             Whisper-Nemo_tiny.en                    after_covid_QANON.json
# 127               Whisper-Nemo_tiny                    after_covid_QANON.json
# 377           Whisper-Nemo_large-v3   after_covid_RELIGIOUS_CONSERVATIVE.json
# 41             Whisper-Nemo_base.en   after_covid_RELIGIOUS_CONSERVATIVE.json
# 405  Whisper-Nemo_large-v3--no-stem   after_covid_RELIGIOUS_CONSERVATIVE.json
# 349           Whisper-Nemo_large-v2   after_covid_RELIGIOUS_CONSERVATIVE.json
# 433                    Whisper-Only   after_covid_RELIGIOUS_CONSERVATIVE.json
# 181              Whisper-Nemo_small   after_covid_RELIGIOUS_CONSERVATIVE.json
# 265              Whisper-Nemo_large   after_covid_RELIGIOUS_CONSERVATIVE.json
# 13        Whisper-Pyannote_large-v3   after_covid_RELIGIOUS_CONSERVATIVE.json
# 125               Whisper-Nemo_tiny   after_covid_RELIGIOUS_CONSERVATIVE.json
# 209          Whisper-Nemo_medium.en   after_covid_RELIGIOUS_CONSERVATIVE.json
# 237             Whisper-Nemo_medium   after_covid_RELIGIOUS_CONSERVATIVE.json
# 69                Whisper-Nemo_base   after_covid_RELIGIOUS_CONSERVATIVE.json
# 153           Whisper-Nemo_small.en   after_covid_RELIGIOUS_CONSERVATIVE.json
# 321           Whisper-Nemo_large-v1   after_covid_RELIGIOUS_CONSERVATIVE.json
# 97             Whisper-Nemo_tiny.en   after_covid_RELIGIOUS_CONSERVATIVE.json
# 293     Whisper-Nemo_large--no-stem   after_covid_RELIGIOUS_CONSERVATIVE.json
# 416  Whisper-Nemo_large-v3--no-stem                after_covid_SOCIALIST.json
# 360           Whisper-Nemo_large-v2                after_covid_SOCIALIST.json
# 80                Whisper-Nemo_base                after_covid_SOCIALIST.json
# 192              Whisper-Nemo_small                after_covid_SOCIALIST.json
# 248             Whisper-Nemo_medium                after_covid_SOCIALIST.json
# 136               Whisper-Nemo_tiny                after_covid_SOCIALIST.json
# 332           Whisper-Nemo_large-v1                after_covid_SOCIALIST.json
# 52             Whisper-Nemo_base.en                after_covid_SOCIALIST.json
# 24        Whisper-Pyannote_large-v3                after_covid_SOCIALIST.json
# 164           Whisper-Nemo_small.en                after_covid_SOCIALIST.json
# 108            Whisper-Nemo_tiny.en                after_covid_SOCIALIST.json
# 388           Whisper-Nemo_large-v3                after_covid_SOCIALIST.json
# 220          Whisper-Nemo_medium.en                after_covid_SOCIALIST.json
# 276              Whisper-Nemo_large                after_covid_SOCIALIST.json
# 444                    Whisper-Only                after_covid_SOCIALIST.json
# 304     Whisper-Nemo_large--no-stem                after_covid_SOCIALIST.json
# 205          Whisper-Nemo_medium.en           after_covid_SOCIAL_JUSTICE.json
# 345           Whisper-Nemo_large-v2           after_covid_SOCIAL_JUSTICE.json
# 233             Whisper-Nemo_medium           after_covid_SOCIAL_JUSTICE.json
# 429                    Whisper-Only           after_covid_SOCIAL_JUSTICE.json
# 373           Whisper-Nemo_large-v3           after_covid_SOCIAL_JUSTICE.json
# 65                Whisper-Nemo_base           after_covid_SOCIAL_JUSTICE.json
# 401  Whisper-Nemo_large-v3--no-stem           after_covid_SOCIAL_JUSTICE.json
# 317           Whisper-Nemo_large-v1           after_covid_SOCIAL_JUSTICE.json
# 9         Whisper-Pyannote_large-v3           after_covid_SOCIAL_JUSTICE.json
# 37             Whisper-Nemo_base.en           after_covid_SOCIAL_JUSTICE.json
# 289     Whisper-Nemo_large--no-stem           after_covid_SOCIAL_JUSTICE.json
# 261              Whisper-Nemo_large           after_covid_SOCIAL_JUSTICE.json
# 93             Whisper-Nemo_tiny.en           after_covid_SOCIAL_JUSTICE.json
# 177              Whisper-Nemo_small           after_covid_SOCIAL_JUSTICE.json
# 121               Whisper-Nemo_tiny           after_covid_SOCIAL_JUSTICE.json
# 149           Whisper-Nemo_small.en           after_covid_SOCIAL_JUSTICE.json
# 385           Whisper-Nemo_large-v3       after_covid_WHITE_IDENTITARIAN.json
# 77                Whisper-Nemo_base       after_covid_WHITE_IDENTITARIAN.json
# 273              Whisper-Nemo_large       after_covid_WHITE_IDENTITARIAN.json
# 49             Whisper-Nemo_base.en       after_covid_WHITE_IDENTITARIAN.json
# 413  Whisper-Nemo_large-v3--no-stem       after_covid_WHITE_IDENTITARIAN.json
# 245             Whisper-Nemo_medium       after_covid_WHITE_IDENTITARIAN.json
# 105            Whisper-Nemo_tiny.en       after_covid_WHITE_IDENTITARIAN.json
# 217          Whisper-Nemo_medium.en       after_covid_WHITE_IDENTITARIAN.json
# 301     Whisper-Nemo_large--no-stem       after_covid_WHITE_IDENTITARIAN.json
# 357           Whisper-Nemo_large-v2       after_covid_WHITE_IDENTITARIAN.json
# 161           Whisper-Nemo_small.en       after_covid_WHITE_IDENTITARIAN.json
# 21        Whisper-Pyannote_large-v3       after_covid_WHITE_IDENTITARIAN.json
# 189              Whisper-Nemo_small       after_covid_WHITE_IDENTITARIAN.json
# 329           Whisper-Nemo_large-v1       after_covid_WHITE_IDENTITARIAN.json
# 133               Whisper-Nemo_tiny       after_covid_WHITE_IDENTITARIAN.json
# 441                    Whisper-Only       after_covid_WHITE_IDENTITARIAN.json
# 51             Whisper-Nemo_base.en                before_covid_ANTI_SJW.json
# 331           Whisper-Nemo_large-v1                before_covid_ANTI_SJW.json
# 107            Whisper-Nemo_tiny.en                before_covid_ANTI_SJW.json
# 191              Whisper-Nemo_small                before_covid_ANTI_SJW.json
# 247             Whisper-Nemo_medium                before_covid_ANTI_SJW.json
# 79                Whisper-Nemo_base                before_covid_ANTI_SJW.json
# 387           Whisper-Nemo_large-v3                before_covid_ANTI_SJW.json
# 163           Whisper-Nemo_small.en                before_covid_ANTI_SJW.json
# 443                    Whisper-Only                before_covid_ANTI_SJW.json
# 359           Whisper-Nemo_large-v2                before_covid_ANTI_SJW.json
# 275              Whisper-Nemo_large                before_covid_ANTI_SJW.json
# 219          Whisper-Nemo_medium.en                before_covid_ANTI_SJW.json
# 303     Whisper-Nemo_large--no-stem                before_covid_ANTI_SJW.json
# 23        Whisper-Pyannote_large-v3                before_covid_ANTI_SJW.json
# 415  Whisper-Nemo_large-v3--no-stem                before_covid_ANTI_SJW.json
# 135               Whisper-Nemo_tiny                before_covid_ANTI_SJW.json
# 333           Whisper-Nemo_large-v1             before_covid_ANTI_THEIST.json
# 305     Whisper-Nemo_large--no-stem             before_covid_ANTI_THEIST.json
# 361           Whisper-Nemo_large-v2             before_covid_ANTI_THEIST.json
# 277              Whisper-Nemo_large             before_covid_ANTI_THEIST.json
# 25        Whisper-Pyannote_large-v3             before_covid_ANTI_THEIST.json
# 109            Whisper-Nemo_tiny.en             before_covid_ANTI_THEIST.json
# 221          Whisper-Nemo_medium.en             before_covid_ANTI_THEIST.json
# 81                Whisper-Nemo_base             before_covid_ANTI_THEIST.json
# 389           Whisper-Nemo_large-v3             before_covid_ANTI_THEIST.json
# 417  Whisper-Nemo_large-v3--no-stem             before_covid_ANTI_THEIST.json
# 193              Whisper-Nemo_small             before_covid_ANTI_THEIST.json
# 445                    Whisper-Only             before_covid_ANTI_THEIST.json
# 249             Whisper-Nemo_medium             before_covid_ANTI_THEIST.json
# 53             Whisper-Nemo_base.en             before_covid_ANTI_THEIST.json
# 137               Whisper-Nemo_tiny             before_covid_ANTI_THEIST.json
# 165           Whisper-Nemo_small.en             before_covid_ANTI_THEIST.json
# 365           Whisper-Nemo_large-v3                   before_covid_BLACK.json
# 197          Whisper-Nemo_medium.en                   before_covid_BLACK.json
# 309           Whisper-Nemo_large-v1                   before_covid_BLACK.json
# 57                Whisper-Nemo_base                   before_covid_BLACK.json
# 421                    Whisper-Only                   before_covid_BLACK.json
# 281     Whisper-Nemo_large--no-stem                   before_covid_BLACK.json
# 393  Whisper-Nemo_large-v3--no-stem                   before_covid_BLACK.json
# 225             Whisper-Nemo_medium                   before_covid_BLACK.json
# 337           Whisper-Nemo_large-v2                   before_covid_BLACK.json
# 113               Whisper-Nemo_tiny                   before_covid_BLACK.json
# 29             Whisper-Nemo_base.en                   before_covid_BLACK.json
# 85             Whisper-Nemo_tiny.en                   before_covid_BLACK.json
# 1         Whisper-Pyannote_large-v3                   before_covid_BLACK.json
# 253              Whisper-Nemo_large                   before_covid_BLACK.json
# 141           Whisper-Nemo_small.en                   before_covid_BLACK.json
# 169              Whisper-Nemo_small                   before_covid_BLACK.json
# 294     Whisper-Nemo_large--no-stem              before_covid_CONSPIRACY.json
# 98             Whisper-Nemo_tiny.en              before_covid_CONSPIRACY.json
# 154           Whisper-Nemo_small.en              before_covid_CONSPIRACY.json
# 434                    Whisper-Only              before_covid_CONSPIRACY.json
# 406  Whisper-Nemo_large-v3--no-stem              before_covid_CONSPIRACY.json
# 322           Whisper-Nemo_large-v1              before_covid_CONSPIRACY.json
# 266              Whisper-Nemo_large              before_covid_CONSPIRACY.json
# 350           Whisper-Nemo_large-v2              before_covid_CONSPIRACY.json
# 210          Whisper-Nemo_medium.en              before_covid_CONSPIRACY.json
# 126               Whisper-Nemo_tiny              before_covid_CONSPIRACY.json
# 182              Whisper-Nemo_small              before_covid_CONSPIRACY.json
# 378           Whisper-Nemo_large-v3              before_covid_CONSPIRACY.json
# 42             Whisper-Nemo_base.en              before_covid_CONSPIRACY.json
# 14        Whisper-Pyannote_large-v3              before_covid_CONSPIRACY.json
# 70                Whisper-Nemo_base              before_covid_CONSPIRACY.json
# 238             Whisper-Nemo_medium              before_covid_CONSPIRACY.json
# 30             Whisper-Nemo_base.en                    before_covid_LGBT.json
# 422                    Whisper-Only                    before_covid_LGBT.json
# 226             Whisper-Nemo_medium                    before_covid_LGBT.json
# 198          Whisper-Nemo_medium.en                    before_covid_LGBT.json
# 58                Whisper-Nemo_base                    before_covid_LGBT.json
# 86             Whisper-Nemo_tiny.en                    before_covid_LGBT.json
# 310           Whisper-Nemo_large-v1                    before_covid_LGBT.json
# 254              Whisper-Nemo_large                    before_covid_LGBT.json
# 170              Whisper-Nemo_small                    before_covid_LGBT.json
# 114               Whisper-Nemo_tiny                    before_covid_LGBT.json
# 2         Whisper-Pyannote_large-v3                    before_covid_LGBT.json
# 282     Whisper-Nemo_large--no-stem                    before_covid_LGBT.json
# 142           Whisper-Nemo_small.en                    before_covid_LGBT.json
# 338           Whisper-Nemo_large-v2                    before_covid_LGBT.json
# 394  Whisper-Nemo_large-v3--no-stem                    before_covid_LGBT.json
# 366           Whisper-Nemo_large-v3                    before_covid_LGBT.json
# 330           Whisper-Nemo_large-v1             before_covid_LIBERTARIAN.json
# 246             Whisper-Nemo_medium             before_covid_LIBERTARIAN.json
# 218          Whisper-Nemo_medium.en             before_covid_LIBERTARIAN.json
# 162           Whisper-Nemo_small.en             before_covid_LIBERTARIAN.json
# 442                    Whisper-Only             before_covid_LIBERTARIAN.json
# 190              Whisper-Nemo_small             before_covid_LIBERTARIAN.json
# 22        Whisper-Pyannote_large-v3             before_covid_LIBERTARIAN.json
# 134               Whisper-Nemo_tiny             before_covid_LIBERTARIAN.json
# 358           Whisper-Nemo_large-v2             before_covid_LIBERTARIAN.json
# 302     Whisper-Nemo_large--no-stem             before_covid_LIBERTARIAN.json
# 414  Whisper-Nemo_large-v3--no-stem             before_covid_LIBERTARIAN.json
# 78                Whisper-Nemo_base             before_covid_LIBERTARIAN.json
# 386           Whisper-Nemo_large-v3             before_covid_LIBERTARIAN.json
# 50             Whisper-Nemo_base.en             before_covid_LIBERTARIAN.json
# 106            Whisper-Nemo_tiny.en             before_covid_LIBERTARIAN.json
# 274              Whisper-Nemo_large             before_covid_LIBERTARIAN.json
# 241             Whisper-Nemo_medium                     before_covid_MRA.json
# 157           Whisper-Nemo_small.en                     before_covid_MRA.json
# 353           Whisper-Nemo_large-v2                     before_covid_MRA.json
# 101            Whisper-Nemo_tiny.en                     before_covid_MRA.json
# 437                    Whisper-Only                     before_covid_MRA.json
# 185              Whisper-Nemo_small                     before_covid_MRA.json
# 17        Whisper-Pyannote_large-v3                     before_covid_MRA.json
# 325           Whisper-Nemo_large-v1                     before_covid_MRA.json
# 381           Whisper-Nemo_large-v3                     before_covid_MRA.json
# 269              Whisper-Nemo_large                     before_covid_MRA.json
# 213          Whisper-Nemo_medium.en                     before_covid_MRA.json
# 73                Whisper-Nemo_base                     before_covid_MRA.json
# 129               Whisper-Nemo_tiny                     before_covid_MRA.json
# 45             Whisper-Nemo_base.en                     before_covid_MRA.json
# 409  Whisper-Nemo_large-v3--no-stem                     before_covid_MRA.json
# 297     Whisper-Nemo_large--no-stem                     before_covid_MRA.json
# 75                Whisper-Nemo_base           before_covid_PARTISAN_LEFT.json
# 47             Whisper-Nemo_base.en           before_covid_PARTISAN_LEFT.json
# 355           Whisper-Nemo_large-v2           before_covid_PARTISAN_LEFT.json
# 383           Whisper-Nemo_large-v3           before_covid_PARTISAN_LEFT.json
# 299     Whisper-Nemo_large--no-stem           before_covid_PARTISAN_LEFT.json
# 103            Whisper-Nemo_tiny.en           before_covid_PARTISAN_LEFT.json
# 271              Whisper-Nemo_large           before_covid_PARTISAN_LEFT.json
# 243             Whisper-Nemo_medium           before_covid_PARTISAN_LEFT.json
# 159           Whisper-Nemo_small.en           before_covid_PARTISAN_LEFT.json
# 411  Whisper-Nemo_large-v3--no-stem           before_covid_PARTISAN_LEFT.json
# 327           Whisper-Nemo_large-v1           before_covid_PARTISAN_LEFT.json
# 215          Whisper-Nemo_medium.en           before_covid_PARTISAN_LEFT.json
# 131               Whisper-Nemo_tiny           before_covid_PARTISAN_LEFT.json
# 187              Whisper-Nemo_small           before_covid_PARTISAN_LEFT.json
# 19        Whisper-Pyannote_large-v3           before_covid_PARTISAN_LEFT.json
# 439                    Whisper-Only           before_covid_PARTISAN_LEFT.json
# 380           Whisper-Nemo_large-v3          before_covid_PARTISAN_RIGHT.json
# 408  Whisper-Nemo_large-v3--no-stem          before_covid_PARTISAN_RIGHT.json
# 436                    Whisper-Only          before_covid_PARTISAN_RIGHT.json
# 44             Whisper-Nemo_base.en          before_covid_PARTISAN_RIGHT.json
# 156           Whisper-Nemo_small.en          before_covid_PARTISAN_RIGHT.json
# 352           Whisper-Nemo_large-v2          before_covid_PARTISAN_RIGHT.json
# 72                Whisper-Nemo_base          before_covid_PARTISAN_RIGHT.json
# 268              Whisper-Nemo_large          before_covid_PARTISAN_RIGHT.json
# 100            Whisper-Nemo_tiny.en          before_covid_PARTISAN_RIGHT.json
# 184              Whisper-Nemo_small          before_covid_PARTISAN_RIGHT.json
# 128               Whisper-Nemo_tiny          before_covid_PARTISAN_RIGHT.json
# 296     Whisper-Nemo_large--no-stem          before_covid_PARTISAN_RIGHT.json
# 16        Whisper-Pyannote_large-v3          before_covid_PARTISAN_RIGHT.json
# 212          Whisper-Nemo_medium.en          before_covid_PARTISAN_RIGHT.json
# 324           Whisper-Nemo_large-v1          before_covid_PARTISAN_RIGHT.json
# 240             Whisper-Nemo_medium          before_covid_PARTISAN_RIGHT.json
# 11        Whisper-Pyannote_large-v3                   before_covid_QANON.json
# 95             Whisper-Nemo_tiny.en                   before_covid_QANON.json
# 235             Whisper-Nemo_medium                   before_covid_QANON.json
# 263              Whisper-Nemo_large                   before_covid_QANON.json
# 291     Whisper-Nemo_large--no-stem                   before_covid_QANON.json
# 403  Whisper-Nemo_large-v3--no-stem                   before_covid_QANON.json
# 123               Whisper-Nemo_tiny                   before_covid_QANON.json
# 179              Whisper-Nemo_small                   before_covid_QANON.json
# 319           Whisper-Nemo_large-v1                   before_covid_QANON.json
# 207          Whisper-Nemo_medium.en                   before_covid_QANON.json
# 151           Whisper-Nemo_small.en                   before_covid_QANON.json
# 67                Whisper-Nemo_base                   before_covid_QANON.json
# 39             Whisper-Nemo_base.en                   before_covid_QANON.json
# 431                    Whisper-Only                   before_covid_QANON.json
# 347           Whisper-Nemo_large-v2                   before_covid_QANON.json
# 375           Whisper-Nemo_large-v3                   before_covid_QANON.json
# 228             Whisper-Nemo_medium  before_covid_RELIGIOUS_CONSERVATIVE.json
# 396  Whisper-Nemo_large-v3--no-stem  before_covid_RELIGIOUS_CONSERVATIVE.json
# 116               Whisper-Nemo_tiny  before_covid_RELIGIOUS_CONSERVATIVE.json
# 256              Whisper-Nemo_large  before_covid_RELIGIOUS_CONSERVATIVE.json
# 32             Whisper-Nemo_base.en  before_covid_RELIGIOUS_CONSERVATIVE.json
# 424                    Whisper-Only  before_covid_RELIGIOUS_CONSERVATIVE.json
# 200          Whisper-Nemo_medium.en  before_covid_RELIGIOUS_CONSERVATIVE.json
# 284     Whisper-Nemo_large--no-stem  before_covid_RELIGIOUS_CONSERVATIVE.json
# 144           Whisper-Nemo_small.en  before_covid_RELIGIOUS_CONSERVATIVE.json
# 88             Whisper-Nemo_tiny.en  before_covid_RELIGIOUS_CONSERVATIVE.json
# 340           Whisper-Nemo_large-v2  before_covid_RELIGIOUS_CONSERVATIVE.json
# 368           Whisper-Nemo_large-v3  before_covid_RELIGIOUS_CONSERVATIVE.json
# 60                Whisper-Nemo_base  before_covid_RELIGIOUS_CONSERVATIVE.json
# 172              Whisper-Nemo_small  before_covid_RELIGIOUS_CONSERVATIVE.json
# 4         Whisper-Pyannote_large-v3  before_covid_RELIGIOUS_CONSERVATIVE.json
# 312           Whisper-Nemo_large-v1  before_covid_RELIGIOUS_CONSERVATIVE.json
# 74                Whisper-Nemo_base               before_covid_SOCIALIST.json
# 18        Whisper-Pyannote_large-v3               before_covid_SOCIALIST.json
# 158           Whisper-Nemo_small.en               before_covid_SOCIALIST.json
# 326           Whisper-Nemo_large-v1               before_covid_SOCIALIST.json
# 214          Whisper-Nemo_medium.en               before_covid_SOCIALIST.json
# 130               Whisper-Nemo_tiny               before_covid_SOCIALIST.json
# 410  Whisper-Nemo_large-v3--no-stem               before_covid_SOCIALIST.json
# 242             Whisper-Nemo_medium               before_covid_SOCIALIST.json
# 186              Whisper-Nemo_small               before_covid_SOCIALIST.json
# 438                    Whisper-Only               before_covid_SOCIALIST.json
# 270              Whisper-Nemo_large               before_covid_SOCIALIST.json
# 46             Whisper-Nemo_base.en               before_covid_SOCIALIST.json
# 354           Whisper-Nemo_large-v2               before_covid_SOCIALIST.json
# 382           Whisper-Nemo_large-v3               before_covid_SOCIALIST.json
# 102            Whisper-Nemo_tiny.en               before_covid_SOCIALIST.json
# 298     Whisper-Nemo_large--no-stem               before_covid_SOCIALIST.json
# 90             Whisper-Nemo_tiny.en          before_covid_SOCIAL_JUSTICE.json
# 34             Whisper-Nemo_base.en          before_covid_SOCIAL_JUSTICE.json
# 342           Whisper-Nemo_large-v2          before_covid_SOCIAL_JUSTICE.json
# 286     Whisper-Nemo_large--no-stem          before_covid_SOCIAL_JUSTICE.json
# 6         Whisper-Pyannote_large-v3          before_covid_SOCIAL_JUSTICE.json
# 426                    Whisper-Only          before_covid_SOCIAL_JUSTICE.json
# 202          Whisper-Nemo_medium.en          before_covid_SOCIAL_JUSTICE.json
# 370           Whisper-Nemo_large-v3          before_covid_SOCIAL_JUSTICE.json
# 118               Whisper-Nemo_tiny          before_covid_SOCIAL_JUSTICE.json
# 258              Whisper-Nemo_large          before_covid_SOCIAL_JUSTICE.json
# 62                Whisper-Nemo_base          before_covid_SOCIAL_JUSTICE.json
# 174              Whisper-Nemo_small          before_covid_SOCIAL_JUSTICE.json
# 230             Whisper-Nemo_medium          before_covid_SOCIAL_JUSTICE.json
# 314           Whisper-Nemo_large-v1          before_covid_SOCIAL_JUSTICE.json
# 398  Whisper-Nemo_large-v3--no-stem          before_covid_SOCIAL_JUSTICE.json
# 146           Whisper-Nemo_small.en          before_covid_SOCIAL_JUSTICE.json
# 171              Whisper-Nemo_small      before_covid_WHITE_IDENTITARIAN.json
# 143           Whisper-Nemo_small.en      before_covid_WHITE_IDENTITARIAN.json
# 255              Whisper-Nemo_large      before_covid_WHITE_IDENTITARIAN.json
# 423                    Whisper-Only      before_covid_WHITE_IDENTITARIAN.json
# 227             Whisper-Nemo_medium      before_covid_WHITE_IDENTITARIAN.json
# 3         Whisper-Pyannote_large-v3      before_covid_WHITE_IDENTITARIAN.json
# 115               Whisper-Nemo_tiny      before_covid_WHITE_IDENTITARIAN.json
# 395  Whisper-Nemo_large-v3--no-stem      before_covid_WHITE_IDENTITARIAN.json
# 283     Whisper-Nemo_large--no-stem      before_covid_WHITE_IDENTITARIAN.json
# 311           Whisper-Nemo_large-v1      before_covid_WHITE_IDENTITARIAN.json
# 87             Whisper-Nemo_tiny.en      before_covid_WHITE_IDENTITARIAN.json
# 59                Whisper-Nemo_base      before_covid_WHITE_IDENTITARIAN.json
# 367           Whisper-Nemo_large-v3      before_covid_WHITE_IDENTITARIAN.json
# 339           Whisper-Nemo_large-v2      before_covid_WHITE_IDENTITARIAN.json
# 199          Whisper-Nemo_medium.en      before_covid_WHITE_IDENTITARIAN.json
# 31             Whisper-Nemo_base.en      before_covid_WHITE_IDENTITARIAN.json
#
#                                         generated_file  yt_video_id       wer
# 48               after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.177889
# 216              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.250208
# 244              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.194514
# 160              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.252702
# 272              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.137988
# 300              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.137988
# 132              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.217789
# 20               after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.124688
# 328              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.164589
# 356              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.194514
# 104              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.254364
# 384              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.128013
# 412              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.137988
# 76               after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.295096
# 440              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.138820
# 188              after_covid_ANTI_SJW_HqIblDLzY_0.json  HqIblDLzY_0  0.204489
# 139           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.172738
# 83            after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.098707
# 111           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.202115
# 223           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.076381
# 195           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.081081
# 55            after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.095182
# 279           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.068155
# 307           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.065805
# 335           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.070505
# 363           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.075206
# 391           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.068155
# 419           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.065805
# 167           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.166863
# 251           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.068155
# 447           after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.103408
# 27            after_covid_ANTI_THEIST_B0Ryo6HcOys.json  B0Ryo6HcOys  0.066980
# 348                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.178382
# 376                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.164021
# 320                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.185941
# 96                  after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.507937
# 124                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.435374
# 404                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.173847
# 292                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.173847
# 40                  after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.275132
# 180                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.180650
# 208                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.164021
# 236                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.145881
# 264                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.154195
# 68                  after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.261527
# 432                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.193500
# 152                 after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.143613
# 12                  after_covid_BLACK_fzvbx25xqnU.json  fzvbx25xqnU  0.168556
# 334            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.047779
# 222            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.044426
# 194            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.045264
# 26             after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.093881
# 138            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.103940
# 446            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.049455
# 362            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.048617
# 82             after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.064543
# 250            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.047779
# 54             after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.074602
# 166            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.043588
# 390            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.037720
# 306            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.036044
# 418            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.036044
# 278            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.041911
# 110            after_covid_CONSPIRACY_kq2E7LBClnY.json  kq2E7LBClnY  0.130763
# 10                   after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.040275
# 290                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.009823
# 234                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.010314
# 122                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.022593
# 206                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.010314
# 262                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.009823
# 318                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.009823
# 94                   after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.015226
# 346                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.009332
# 150                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.007367
# 374                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.010314
# 402                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.009823
# 38                   after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.006385
# 66                   after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.018664
# 178                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.013261
# 430                  after_covid_LGBT_-roa8M8hT-E.json  -roa8M8hT-E  0.016208
# 36            after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.313514
# 428           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.236486
# 232           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.207432
# 288           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.132432
# 148           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.193919
# 260           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.133784
# 120           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.585811
# 400           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.132432
# 204           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.187838
# 176           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.191892
# 92            after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.317568
# 64            after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.335135
# 344           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.164189
# 316           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.230405
# 372           after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.127027
# 8             after_covid_LIBERTARIAN_mCT9Zt0fdTk.json  mCT9Zt0fdTk  0.216216
# 259                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.022742
# 343                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.024691
# 35                    after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.032489
# 7                     after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.034438
# 203                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.022742
# 427                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.025341
# 231                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.029240
# 91                    after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.041585
# 63                    after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.037037
# 371                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.022742
# 147                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.035088
# 399                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.023392
# 175                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.029890
# 315                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.021442
# 287                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.023392
# 119                   after_covid_MRA_R67v_ySKcj8.json  R67v_ySKcj8  0.040286
# 196         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.024229
# 140         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.019824
# 168         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.020558
# 224         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.022026
# 0           after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.071219
# 364         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.021292
# 336         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.022761
# 56          after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.029369
# 28          after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.019824
# 84          after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.028634
# 392         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.029369
# 308         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.022761
# 252         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.021292
# 420         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.060206
# 280         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.029369
# 112         after_covid_PARTISAN_LEFT_QCHpJkQI7T0.json  QCHpJkQI7T0  0.043319
# 369        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.051190
# 5          after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.021429
# 173        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.038095
# 425        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.042857
# 33         after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.041667
# 61         after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.041667
# 397        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.051190
# 145        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.052381
# 117        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.070238
# 313        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.044048
# 341        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.040476
# 257        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.051190
# 89         after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.057143
# 229        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.041667
# 201        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.046429
# 285        after_covid_PARTISAN_RIGHT_1C888mSyD7s.json  1C888mSyD7s  0.051190
# ...
# 389          before_covid_ANTI_THEIST_MRCtE63-_zA.json  MRCtE63-_zA  0.080177
# 417          before_covid_ANTI_THEIST_MRCtE63-_zA.json  MRCtE63-_zA  0.080177
# 193          before_covid_ANTI_THEIST_MRCtE63-_zA.json  MRCtE63-_zA  0.085227
# 445          before_covid_ANTI_THEIST_MRCtE63-_zA.json  MRCtE63-_zA  0.075126
# 249          before_covid_ANTI_THEIST_MRCtE63-_zA.json  MRCtE63-_zA  0.114268
# 53           before_covid_ANTI_THEIST_MRCtE63-_zA.json  MRCtE63-_zA  0.094066
# 137          before_covid_ANTI_THEIST_MRCtE63-_zA.json  MRCtE63-_zA  0.137626
# 165          before_covid_ANTI_THEIST_MRCtE63-_zA.json  MRCtE63-_zA  0.080177
# 365                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.053595
# 197                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.053595
# 309                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.054902
# 57                 before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.107190
# 421                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.048366
# 281                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.049673
# 393                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.049673
# 225                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.052288
# 337                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.047059
# 113                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.132026
# 29                 before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.073203
# 85                 before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.099346
# 1                  before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.082353
# 253                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.053595
# 141                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.050980
# 169                before_covid_BLACK_zntF4S00T5U.json  zntF4S00T5U  0.074510
# 294           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.093572
# 98            before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.187144
# 154           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.139951
# 434           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.101709
# 406           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.093572
# 322           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.117982
# 266           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.135069
# 350           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.124491
# 210           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.140765
# 126           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.244915
# 182           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.103336
# 378           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.117982
# 42            before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.165989
# 14            before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.122050
# 70            before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.166802
# 238           before_covid_CONSPIRACY_QEidCVusDkY.json  QEidCVusDkY  0.155411
# 30                  before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.077731
# 422                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.058298
# 226                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.064076
# 198                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.116597
# 58                  before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.077206
# 86                  before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.084034
# 310                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.118697
# 254                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.063550
# 170                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.072479
# 114                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.095588
# 2                   before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.080882
# 282                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.067227
# 142                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.090861
# 338                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.088235
# 394                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.067227
# 366                 before_covid_LGBT_21ZfGPp-Ves.json  21ZfGPp-Ves  0.069328
# 330          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.278242
# 246          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.262104
# 218          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.220924
# 162          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.298275
# 442          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.327769
# 190          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.347802
# 22           before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.287702
# 134          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.723428
# 358          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.253756
# 302          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.204229
# 414          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.204229
# 78           before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.449082
# 386          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.183639
# 50           before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.361714
# 106          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.491375
# 274          before_covid_LIBERTARIAN_xhC-dQBRW0Q.json  xhC-dQBRW0Q  0.191987
# 241                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.025307
# 157                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.028200
# 353                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.023861
# 101                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.039046
# 437                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.032538
# 185                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.026030
# 17                   before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.023138
# 325                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.028200
# 381                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.022415
# 269                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.021692
# 213                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.023861
# 73                   before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.035430
# 129                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.050615
# 45                   before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.032538
# 409                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.023138
# 297                  before_covid_MRA_QHici7k3N8s.json  QHici7k3N8s  0.023138
# 75         before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.097162
# 47         before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.078603
# 355        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.055131
# 383        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.059498
# 299        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.076965
# 103        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.081878
# 271        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.059498
# 243        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.061681
# 159        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.101528
# 411        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.076965
# 327        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.061681
# 215        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.063865
# 131        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.185590
# 187        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.075873
# 19         before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.061135
# 439        before_covid_PARTISAN_LEFT_uApSEOBD_qM.json  uApSEOBD_qM  0.052402
# 380       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.088259
# 408       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.074494
# 436       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.062348
# 44        before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.100405
# 156       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.106073
# 352       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.101215
# 72        before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.108502
# 268       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.075304
# 100       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.106883
# 184       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.106073
# 128       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.131174
# 296       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.074494
# 16        before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.097976
# 212       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.115789
# 324       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.095547
# 240       before_covid_PARTISAN_RIGHT_3lfwkTsJGYA.json  3lfwkTsJGYA  0.115789
# 11                 before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.079576
# 95                 before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.097259
# 235                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.055703
# 263                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.050398
# 291                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.052166
# 403                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.052166
# 123                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.097259
# 179                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.060124
# 319                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.048630
# 207                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.051282
# 151                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.059240
# 67                 before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.060124
# 39                 before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.061008
# 431                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.049514
# 347                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.052166
# 375                before_covid_QANON_UDrfDAWA5Ig.json  UDrfDAWA5Ig  0.055703
# 228  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.080415
# 396  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.084306
# 116  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.084306
# 256  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.084306
# 32   before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.079118
# 424  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.105058
# 200  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.102464
# 284  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.084306
# 144  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.076524
# 88   before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.085603
# 340  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.111543
# 368  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.084306
# 60   before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.073930
# 172  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.075227
# 4    before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.119326
# 312  before_covid_RELIGIOUS_CONSERVATIVE_Fdfru9NHGv...  Fdfru9NHGvE  0.114137
# 74             before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.058399
# 18             before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.035521
# 158            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.054184
# 326            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.043347
# 214            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.044551
# 130            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.071644
# 410            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.043347
# 242            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.046960
# 186            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.046358
# 438            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.043347
# 270            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.042745
# 46             before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.059603
# 354            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.059001
# 382            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.042745
# 102            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.065021
# 298            before_covid_SOCIALIST_gBMmcX-5INQ.json  gBMmcX-5INQ  0.043347
# 90        before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.265004
# 34        before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.194076
# 342       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.069369
# 286       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.088854
# 6         before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.101325
# 426       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.095090
# 202       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.077942
# 370       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.073266
# 118       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.363991
# 258       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.074045
# 62        before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.210444
# 174       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.093531
# 230       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.065472
# 314       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.097428
# 398       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.088854
# 146       before_covid_SOCIAL_JUSTICE_gEabswbUNdw.json  gEabswbUNdw  0.080281
# 171   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.017216
# 143   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.016467
# 255   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.020210
# 423   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.032934
# 227   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.014970
# 3     before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.050150
# 115   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.029940
# 395   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.022455
# 283   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.022455
# 311   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.032934
# 87    before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.021707
# 59    before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.020958
# 367   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.017964
# 339   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.017216
# 199   before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.032186
# 31    before_covid_WHITE_IDENTITARIAN_R3ODk0_rA44.json  R3ODk0_rA44  0.013473

# %%
# Group by model and calculate average WER
average_wer = results_df.groupby('model')['wer'].mean().reset_index()
average_wer

# Plotting the results with detailed values on top of bars
plt.figure(figsize=(10, 6))
bars = plt.bar(average_wer['model'], average_wer['wer'], color='skyblue')

# Add detailed values on top of bars
for bar, value in zip(bars, average_wer['wer']):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2.0, height, f'{value:.4f}', ha='center', va='bottom')

plt.xlabel('Model')
plt.ylabel('Average WER')
plt.title('Average WER by Model')
plt.xticks(rotation=45)
plt.show()
