# %%
import re
import umap
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import glob
import numpy as np

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
# File paths assuming you have all .md files in the specified directory
file_paths = glob.glob("data_combined/*.md")

# Flag to control whether to consider topic counts or not
consider_count = True  # Set to True to consider counts, or False to ignore them

# Initialize lists for storing topics, their counts, and their ideology
all_topics = []
all_ideologies = []
topic_counts = []

# Regular expression pattern to match the topic and count
pattern = re.compile(r"\[1\] (.+?) \(Count: (\d+)\):")

# Process each file
for file_path in file_paths:
    ideology_name = file_path.split('/')[-1].replace('.md', '')
    
    # Read and parse each line in the file
    with open(file_path, 'r') as file:
        for line in file:
            matches = pattern.findall(line)
            for match in matches:
                topic = match[0].strip()
                count = int(match[1].strip())
                # Store topic, ideology, and count
                all_topics.append(topic)
                all_ideologies.append(ideology_name)
                topic_counts.append(count)

# Load a pre-trained SentenceTransformer model
model = SentenceTransformer('all-mpnet-base-v2')  # You can choose a different model as needed

# Generate semantic embeddings for the topics
X = model.encode(all_topics)

if consider_count:
    # Multiply embeddings by the square root of the counts to give weight to more frequent topics
    weighted_embeddings = np.array([embedding * np.sqrt(count) for embedding, count in zip(X, topic_counts)])
else:
    # Use embeddings as-is, without considering topic counts
    weighted_embeddings = X

# Perform UMAP dimensionality reduction
reducer = umap.UMAP(n_components=2, random_state=42)
embeddings = reducer.fit_transform(weighted_embeddings)

# Cluster the topics using KMeans
n_clusters = 5  # You can adjust the number of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(embeddings)

# Get the cluster centers for labeling
cluster_centers = kmeans.cluster_centers_
# Out:
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
# Plotting the result
plt.figure(figsize=(14, 10))
for ideology_name in set(all_ideologies):
    indices = [i for i, ideology in enumerate(all_ideologies) if ideology == ideology_name]
    plt.scatter(embeddings[indices, 0], embeddings[indices, 1], label=ideology_name, alpha=0.7)

# Label each cluster with the most common topic in the cluster
for cluster_idx in range(n_clusters):
    # Get the indices of topics in this cluster
    cluster_topic_indices = np.where(labels == cluster_idx)[0]
    
    # Get the most common topic in the cluster
    cluster_topics = [all_topics[i] for i in cluster_topic_indices]
    most_common_topic = max(set(cluster_topics), key=cluster_topics.count)
    
    # Plot the label at the cluster center
    plt.text(cluster_centers[cluster_idx, 0], cluster_centers[cluster_idx, 1], 
             most_common_topic, fontsize=12, ha='center', color='black')

plt.title("Topic Analysis Across Ideologies with Cluster Labels")
plt.legend(loc='best', fontsize='small')
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.show()

# %%
# File paths assuming you have all .md files in the specified directory
file_paths = glob.glob("data_after/*.md")

# Flag to control whether to consider topic counts or not
consider_count = False  # Set to True to consider counts, or False to ignore them

# Initialize lists for storing topics, their counts, and their ideology
all_topics = []
all_ideologies = []
topic_counts = []

# Regular expression pattern to match the topic and count
pattern = re.compile(r"\[1\] (.+?) \(Count: (\d+)\):")

# Process each file
for file_path in file_paths:
    ideology_name = file_path.split('/')[-1].replace('.md', '')
    
    # Read and parse each line in the file
    with open(file_path, 'r') as file:
        for line in file:
            matches = pattern.findall(line)
            for match in matches:
                topic = match[0].strip()
                count = int(match[1].strip())
                # Store topic, ideology, and count
                all_topics.append(topic)
                all_ideologies.append(ideology_name)
                topic_counts.append(count)

# Load a pre-trained SentenceTransformer model
model = SentenceTransformer('all-mpnet-base-v2')  # You can choose a different model as needed

# Generate semantic embeddings for the topics
X = model.encode(all_topics)

if consider_count:
    # Multiply embeddings by the square root of the counts to give weight to more frequent topics
    weighted_embeddings = np.array([embedding * np.sqrt(count) for embedding, count in zip(X, topic_counts)])
else:
    # Use embeddings as-is, without considering topic counts
    weighted_embeddings = X

# Perform UMAP dimensionality reduction
reducer = umap.UMAP(n_components=2, random_state=42)
embeddings = reducer.fit_transform(weighted_embeddings)

# Cluster the topics using KMeans
n_clusters = 5  # You can adjust the number of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(embeddings)

# Get the cluster centers for labeling
cluster_centers = kmeans.cluster_centers_
# Out:
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
# Plotting the result
plt.figure(figsize=(14, 10))
for ideology_name in set(all_ideologies):
    indices = [i for i, ideology in enumerate(all_ideologies) if ideology == ideology_name]
    plt.scatter(embeddings[indices, 0], embeddings[indices, 1], label=ideology_name, alpha=0.7)

# Label each cluster with the most common topic in the cluster
for cluster_idx in range(n_clusters):
    # Get the indices of topics in this cluster
    cluster_topic_indices = np.where(labels == cluster_idx)[0]
    
    # Get the most common topic in the cluster
    cluster_topics = [all_topics[i] for i in cluster_topic_indices]
    most_common_topic = max(set(cluster_topics), key=cluster_topics.count)
    
    # Plot the label at the cluster center
    plt.text(cluster_centers[cluster_idx, 0], cluster_centers[cluster_idx, 1], 
             most_common_topic, fontsize=12, ha='center', color='black')

plt.title("Topic Analysis Across Ideologies with Cluster Labels")
plt.legend(loc='best', fontsize='small')
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.show()

# %%
# File paths assuming you have all .md files in the specified directory
file_paths = glob.glob("data_refined_before/*.jsonl")

# Flag to control whether to consider topic counts or not
consider_count = True  # Set to True to consider counts, or False to ignore them

# Initialize lists for storing topics, their counts, and their ideology
all_topics = []
all_ideologies = []
topic_counts = []

# Regular expression pattern to match the topic and count
pattern = re.compile(r"\[1\] (.+?) \(Count: (\d+)\):")

# Process each file
for file_path in file_paths:
    ideology_name = file_path.split('/')[-1].replace('.jsonl', '')
    
    # Read and parse each line in the file
    with open(file_path, 'r') as file:
        for line in file:
            matches = pattern.findall(line)
            for match in matches:
                topic = match[0].strip()
                count = int(match[1].strip())
                # Store topic, ideology, and count
                all_topics.append(topic)
                all_ideologies.append(ideology_name)
                topic_counts.append(count)

# Load a pre-trained SentenceTransformer model
model = SentenceTransformer('all-mpnet-base-v2')  # You can choose a different model as needed

# Generate semantic embeddings for the topics
X = model.encode(all_topics)

if consider_count:
    # Multiply embeddings by the square root of the counts to give weight to more frequent topics
    weighted_embeddings = np.array([embedding * np.sqrt(count) for embedding, count in zip(X, topic_counts)])
else:
    # Use embeddings as-is, without considering topic counts
    weighted_embeddings = X

# Perform UMAP dimensionality reduction
reducer = umap.UMAP(n_components=2, random_state=42)
embeddings = reducer.fit_transform(weighted_embeddings)

# Cluster the topics using KMeans
n_clusters = 20  # You can adjust the number of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(embeddings)

# Get the cluster centers for labeling
cluster_centers = kmeans.cluster_centers_
# Out:
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
# Plotting the result
plt.figure(figsize=(14, 10))
for ideology_name in set(all_ideologies):
    indices = [i for i, ideology in enumerate(all_ideologies) if ideology == ideology_name]
    plt.scatter(embeddings[indices, 0], embeddings[indices, 1], label=ideology_name, alpha=0.7)

# Label each cluster with the most common topic in the cluster
for cluster_idx in range(n_clusters):
    # Get the indices of topics in this cluster
    cluster_topic_indices = np.where(labels == cluster_idx)[0]
    
    # Get the most common topic in the cluster
    cluster_topics = [all_topics[i] for i in cluster_topic_indices]
    most_common_topic = max(set(cluster_topics), key=cluster_topics.count)
    
    # Plot the label at the cluster center
    plt.text(cluster_centers[cluster_idx, 0], cluster_centers[cluster_idx, 1], 
             most_common_topic, fontsize=12, ha='center', color='black')

plt.title("Topic Analysis Across Ideologies with Cluster Labels")
plt.legend(loc='best', fontsize='small')
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.show()

# %%
# File paths assuming you have all .md files in the specified directory
file_paths = glob.glob("data_refined_after/*.jsonl")

# Flag to control whether to consider topic counts or not
consider_count = True  # Set to True to consider counts, or False to ignore them

# Initialize lists for storing topics, their counts, and their ideology
all_topics = []
all_ideologies = []
topic_counts = []

# Regular expression pattern to match the topic and count
pattern = re.compile(r"\[1\] (.+?) \(Count: (\d+)\):")

# Process each file
for file_path in file_paths:
    ideology_name = file_path.split('/')[-1].replace('.jsonl', '')
    
    # Read and parse each line in the file
    with open(file_path, 'r') as file:
        for line in file:
            matches = pattern.findall(line)
            for match in matches:
                topic = match[0].strip()
                count = int(match[1].strip())
                # Store topic, ideology, and count
                all_topics.append(topic)
                all_ideologies.append(ideology_name)
                topic_counts.append(count)

# Load a pre-trained SentenceTransformer model
model = SentenceTransformer('all-mpnet-base-v2')  # You can choose a different model as needed

# Generate semantic embeddings for the topics
X = model.encode(all_topics)

if consider_count:
    # Multiply embeddings by the square root of the counts to give weight to more frequent topics
    weighted_embeddings = np.array([embedding * np.sqrt(count) for embedding, count in zip(X, topic_counts)])
else:
    # Use embeddings as-is, without considering topic counts
    weighted_embeddings = X

# Perform UMAP dimensionality reduction
reducer = umap.UMAP(n_components=2, random_state=42)
embeddings = reducer.fit_transform(weighted_embeddings)

# Cluster the topics using KMeans
n_clusters = 20  # You can adjust the number of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(embeddings)

# Get the cluster centers for labeling
cluster_centers = kmeans.cluster_centers_
# Out:
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
# Plotting the result
plt.figure(figsize=(14, 10))
for ideology_name in set(all_ideologies):
    indices = [i for i, ideology in enumerate(all_ideologies) if ideology == ideology_name]
    plt.scatter(embeddings[indices, 0], embeddings[indices, 1], label=ideology_name, alpha=0.7)

# Label each cluster with the most common topic in the cluster
for cluster_idx in range(n_clusters):
    # Get the indices of topics in this cluster
    cluster_topic_indices = np.where(labels == cluster_idx)[0]
    
    # Get the most common topic in the cluster
    cluster_topics = [all_topics[i] for i in cluster_topic_indices]
    most_common_topic = max(set(cluster_topics), key=cluster_topics.count)
    
    # Plot the label at the cluster center
    plt.text(cluster_centers[cluster_idx, 0], cluster_centers[cluster_idx, 1], 
             most_common_topic, fontsize=12, ha='center', color='black')

plt.title("Topic Analysis Across Ideologies with Cluster Labels")
plt.legend(loc='best', fontsize='small')
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.show()

# %%
# File paths assuming you have all .md files in the specified directory
file_paths = glob.glob("data_refined_before_latest/*.md")

# Flag to control whether to consider topic counts or not
consider_count = True  # Set to True to consider counts, or False to ignore them

# Initialize lists for storing topics, their counts, and their ideology
all_topics = []
all_ideologies = []
topic_counts = []

# Regular expression pattern to match the topic and count
pattern = re.compile(r"\[1\] (.+?) \(Count: (\d+)\):")

# Process each file
for file_path in file_paths:
    ideology_name = file_path.split('/')[-1].replace('.md', '')
    
    # Read and parse each line in the file
    with open(file_path, 'r') as file:
        for line in file:
            matches = pattern.findall(line)
            for match in matches:
                topic = match[0].strip()
                count = int(match[1].strip())
                # Store topic, ideology, and count
                all_topics.append(topic)
                all_ideologies.append(ideology_name)
                topic_counts.append(count)

# Load a pre-trained SentenceTransformer model
model = SentenceTransformer('all-mpnet-base-v2')  # You can choose a different model as needed

# Generate semantic embeddings for the topics
X = model.encode(all_topics)

if consider_count:
    # Multiply embeddings by the square root of the counts to give weight to more frequent topics
    weighted_embeddings = np.array([embedding * np.sqrt(count) for embedding, count in zip(X, topic_counts)])
else:
    # Use embeddings as-is, without considering topic counts
    weighted_embeddings = X

# Perform UMAP dimensionality reduction
reducer = umap.UMAP(n_components=2, random_state=42)
embeddings = reducer.fit_transform(weighted_embeddings)

# Cluster the topics using KMeans
n_clusters = 20  # You can adjust the number of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(embeddings)

# Get the cluster centers for labeling
cluster_centers = kmeans.cluster_centers_
# Out:
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
# Plotting the result
plt.figure(figsize=(14, 10))
for ideology_name in set(all_ideologies):
    indices = [i for i, ideology in enumerate(all_ideologies) if ideology == ideology_name]
    plt.scatter(embeddings[indices, 0], embeddings[indices, 1], label=ideology_name, alpha=0.7)

# Label each cluster with the most common topic in the cluster
for cluster_idx in range(n_clusters):
    # Get the indices of topics in this cluster
    cluster_topic_indices = np.where(labels == cluster_idx)[0]
    
    # Get the most common topic in the cluster
    cluster_topics = [all_topics[i] for i in cluster_topic_indices]
    most_common_topic = max(set(cluster_topics), key=cluster_topics.count)
    
    # Plot the label at the cluster center
    plt.text(cluster_centers[cluster_idx, 0], cluster_centers[cluster_idx, 1], 
             most_common_topic, fontsize=12, ha='center', color='black')

plt.title("Topic Analysis Across Ideologies with Cluster Labels")
plt.legend(loc='best', fontsize='small')
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.show()

# %%
# File paths assuming you have all .md files in the specified directory
file_paths = glob.glob("data_refined_after_latest/*.md")

# Flag to control whether to consider topic counts or not
consider_count = True  # Set to True to consider counts, or False to ignore them

# Initialize lists for storing topics, their counts, and their ideology
all_topics = []
all_ideologies = []
topic_counts = []

# Regular expression pattern to match the topic and count
pattern = re.compile(r"\[1\] (.+?) \(Count: (\d+)\):")

# Process each file
for file_path in file_paths:
    ideology_name = file_path.split('/')[-1].replace('.md', '')
    
    # Read and parse each line in the file
    with open(file_path, 'r') as file:
        for line in file:
            matches = pattern.findall(line)
            for match in matches:
                topic = match[0].strip()
                count = int(match[1].strip())
                # Store topic, ideology, and count
                all_topics.append(topic)
                all_ideologies.append(ideology_name)
                topic_counts.append(count)

# Load a pre-trained SentenceTransformer model
model = SentenceTransformer('all-mpnet-base-v2')  # You can choose a different model as needed

# Generate semantic embeddings for the topics
X = model.encode(all_topics)

if consider_count:
    # Multiply embeddings by the square root of the counts to give weight to more frequent topics
    weighted_embeddings = np.array([embedding * np.sqrt(count) for embedding, count in zip(X, topic_counts)])
else:
    # Use embeddings as-is, without considering topic counts
    weighted_embeddings = X

# Perform UMAP dimensionality reduction
reducer = umap.UMAP(n_components=2, random_state=42)
embeddings = reducer.fit_transform(weighted_embeddings)

# Cluster the topics using KMeans
n_clusters = 20  # You can adjust the number of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(embeddings)

# Get the cluster centers for labeling
cluster_centers = kmeans.cluster_centers_
# Out:
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
# Plotting the result
plt.figure(figsize=(14, 10))
for ideology_name in set(all_ideologies):
    indices = [i for i, ideology in enumerate(all_ideologies) if ideology == ideology_name]
    plt.scatter(embeddings[indices, 0], embeddings[indices, 1], label=ideology_name, alpha=0.7)

# Label each cluster with the most common topic in the cluster
for cluster_idx in range(n_clusters):
    # Get the indices of topics in this cluster
    cluster_topic_indices = np.where(labels == cluster_idx)[0]
    
    # Get the most common topic in the cluster
    cluster_topics = [all_topics[i] for i in cluster_topic_indices]
    most_common_topic = max(set(cluster_topics), key=cluster_topics.count)
    
    # Plot the label at the cluster center
    plt.text(cluster_centers[cluster_idx, 0], cluster_centers[cluster_idx, 1], 
             most_common_topic, fontsize=12, ha='center', color='black')

plt.title("Topic Analysis Across Ideologies with Cluster Labels")
plt.legend(loc='best', fontsize='small')
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.show()
