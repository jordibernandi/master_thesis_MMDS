# %%
import os
import re
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
import umap
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Load a pre-trained sentence transformer model
model = SentenceTransformer("Alibaba-NLP/gte-large-en-v1.5", trust_remote_code=True)

# Set the folder containing the files
folder_path = "../Llama3_1_Model_2/topicGPT/data/output/FINAL"

# List of unique ideologies
ideologies = ["ANTI_SJW", "ANTI_THEIST", "BLACK", "CONSPIRACY", "LGBT", "LIBERTARIAN", 
              "MRA", "PARTISAN_RIGHT", "PARTISAN_LEFT", "QANON", "RELIGIOUS_CONSERVATIVE", 
              "SOCIAL_JUSTICE", "SOCIALIST", "WHITE_IDENTITARIAN"]
# ideologies = ["ANTI_SJW"]

# Function to extract main topic and its subtopics dynamically based on a specified topic name
def extract_main_topic(file_path, main_topic="Politics", subtopic_limit=10):
    try:
        with open(file_path, 'r') as file:
            data = file.read()

        # Regex to match the main topic and extract its description
        main_topic_pattern = re.compile(rf'\[1\] {main_topic} \(Count: \d+\): (.*?)\n')
        
        # Updated regex pattern to capture subtopic, count (optional), and description
        subtopic_pattern = re.compile(r'\[2\] ([^()]*?)(?: \(Count:\s*(\d+)\))?: (.*?)\n')

        # Find the section for the specified main topic
        main_topic_match = main_topic_pattern.search(data)
        if not main_topic_match:
            return f"Main topic '{main_topic}' not found."

        # Extract the description for the main topic
        main_topic_description = main_topic_match.group(1).strip()

        # Find the position of the main topic
        start_pos = main_topic_match.end()
        
        # Find the next main topic or the end of the string
        next_main_topic = re.search(r'\[1\]', data[start_pos:])
        end_pos = start_pos + (next_main_topic.start() if next_main_topic else len(data))

        # Extract the section related to the main topic
        section = data[start_pos:end_pos]

        # Extract all subtopics, their counts, and their descriptions
        subtopics = subtopic_pattern.findall(section)

        # Filter out subtopics with no count (count is None or empty)
        subtopics_with_counts = [(subtopic.strip(), int(count) if count else 0, description.strip()) for subtopic, count, description in subtopics]

        # Sort subtopics by count in descending order
        subtopics_with_counts.sort(key=lambda x: x[1], reverse=True)

        # Apply the subtopic limit if specified
        if subtopic_limit is not None:
            subtopics_with_counts = subtopics_with_counts[:subtopic_limit]

        # Format the subtopics to include count and description
        subtopics_list = [
            f"{subtopic}: {description}"
            for subtopic, count, description in subtopics_with_counts
        ]

        # Return a structured dictionary with main topic, description, and subtopics
        return {
            "main_topic": f"{main_topic.strip()}: {main_topic_description.strip()}",
            "subtopics": subtopics_list
        }
    except FileNotFoundError:
        print(f"File {file_path} not found.")
        return {}

# Function to generate embeddings for a text input using SentenceTransformer
def get_embedding(text):
    return model.encode(text)

# DataFrame to hold extracted data
data = []

# Main topic to analyze (can be changed dynamically)
main_topic = "Politics"

# Iterate over unique ideologies and time phases
for ideology in ideologies:
    for time_phase in ["after", "before"]:  # Check both after and before files
        
        # Construct markdown filename
        md_filename = f"generation_2_{time_phase}_{ideology}_1Topic_politics.md"
        md_file_path = os.path.join(folder_path, md_filename)
        
        # Extract only the specified main topic and subtopics
        topics = extract_main_topic(md_file_path, main_topic)
       
        if topics:
            combined_text = f"[Main Topic] {topics['main_topic']}"

            if len(topics["subtopics"]) > 0:
                # Combine all subtopics into one text block for embedding (ignoring counts)
                combined_text = combined_text + " [Subtopics]" + ' '.join([f"{topic}" for topic in topics['subtopics']])

            print( print("Period", time_phase)
        print("Ideology: ", ideology))
            # Get the embedding for the combined text
            embedding = get_embedding(combined_text)
            
            # Append the data
            data.append({
                "ideology": ideology,
                "period": time_phase,
                "embedding": embedding
            })

# Convert data into a DataFrame
df = pd.DataFrame(data)

# Extract embeddings and labels
X = np.array(df['embedding'].tolist())  # Embeddings
y_ideology = df['ideology']  # Ideology
y_period = df['period']  # Period (before/after)

# Label encode the ideologies for visualization
le_ideology = LabelEncoder()
y_ideology_encoded = le_ideology.fit_transform(y_ideology)

# Apply UMAP to project the embeddings into a lower-dimensional space (2D)
umap_model = umap.UMAP(n_components=2, random_state=42)
X_umap = umap_model.fit_transform(X)

# Plot the UMAP projection to visualize ideologies with labels
plt.figure(figsize=(12, 8))
colors = {'before': 'blue', 'after': 'green'}
markers = {'before': 'o', 'after': 's'}

# To track whether we have added a label for each period
label_added = {'before': False, 'after': False}

for i, (x, y, ideology, period) in enumerate(zip(X_umap[:, 0], X_umap[:, 1], df['ideology'], df['period'])):
    # Add label for the legend only once per period
    if not label_added[period]:
        plt.scatter(x, y, color=colors[period], marker=markers[period], label=f'Period: {period}', alpha=0.7)
        label_added[period] = True
    else:
        plt.scatter(x, y, color=colors[period], marker=markers[period], alpha=0.7)
    
    # Annotate the points with ideology
    plt.annotate(ideology, (x, y), fontsize=9, alpha=0.8)

# Set up the plot details
plt.title("UMAP Projection of Ideologies (Before and After COVID)")
plt.xlabel("UMAP Component 1")
plt.ylabel("UMAP Component 2")
plt.legend(loc='best')  # Legend showing both periods
plt.grid(True)
plt.show()

# Analyze cosine similarity between ideologies before and after COVID
similarities = {}
for ideology in le_ideology.classes_:
    before_emb = X_umap[(df['ideology'] == ideology) & (df['period'] == 'before')]
    after_emb = X_umap[(df['ideology'] == ideology) & (df['period'] == 'after')]
    
    if before_emb.shape[0] > 0 and after_emb.shape[0] > 0:
        # Calculate cosine similarity between embeddings before and after COVID for each ideology
        sim = cosine_similarity(before_emb.mean(axis=0).reshape(1, -1), 
                                after_emb.mean(axis=0).reshape(1, -1))[0][0]
        similarities[ideology] = sim

# Output the cosine similarity results
print(f"Cosine Similarity between Ideologies Before and After COVID ({main_topic} only):")
for ideology, similarity in similarities.items():
    print(f"{ideology}: {similarity:.4f}")
# Out:
# Period after
# Ideology:  ANTI_SJW
# Topics:  {'main_topic': 'Politics: Mentions policies, debates, and government actions.', 'subtopics': ['Social Justice: Mentions issues related to equality, fairness, and human rights.', "Government Accountability: Mentions the controversy surrounding Cabinet Minister Patty Hajdu's use of a private government jet and the government's treatment of civil servants during the pandemic.", "Public Health: Mentions the President's decision to stop China from entering the US and the impact of social distancing guidelines.", "Patriotism: Mentions the speaker's love for America and its diversity.", "Public Opinion: Mentions the speaker's criticism of President Joe Biden's stance on gun control.", "Police Reform: Mentions the protesters' stance on the police and their support for Black Lives Matter.", "National Security: Mentions the President's decision to stop China from entering the US.", "Social Activism: Mentions the protesters' stance on the police and their support for Black Lives Matter.", "Media Bias: Mentions the controversy surrounding Twitch's attire guidelines and the throttling of the New York Post article on social media.", "Social Media Regulation: Mentions the controversy surrounding Twitch's attire guidelines and the throttling of the New York Post article on social media."]}
# Period before
# Ideology:  ANTI_SJW
# Topics:  {'main_topic': 'Politics: Mentions the influence of political agendas on businesses and the impact of divisive policies.', 'subtopics': ['Social Unrest: Mentions the LA Riots, Roof Koreans, and violent interactions between pro-Trump and anti-Trump groups.', "Free Speech: Mentions a heated discussion on a YouTube show, YouTube's crackdown on Steven Crowder, and an argument between Ben Shapiro and Beto O'Rourke.", "Media Bias: Mentions the mainstream media's failure to report on several significant stories, including a California bill that would have taught public school students that capitalism is racist and encouraged participation in the anti-Semitic BDS movement.", "Immigration: Mentions undocumented immigrants, immigrants not wearing poppies on Remembrance Day, and the Democratic Party's failures in Baltimore.", 'Government Accountability: Mentions the conclusion of the Mueller investigation and the lack of indictments.', 'Pop Culture: Mentions a discussion about the movie Captain Marvel and its mixed reviews.', "Gun Rights: Mentions an argument between Ben Shapiro and Beto O'Rourke about parental rights, LGBTQ rights, and gun ownership.", 'Abortion: Mentions a debate outside George Washington University in D.C. regarding abortion rights.', 'Education: Mentions a discussion about providing taxpayer-funded free tuition to undocumented immigrants.', "Climate Change: Mentions the Green New Deal and the Senate's vote on the proposal."]}
# Period after
# Ideology:  ANTI_THEIST
# Topics:  {'main_topic': 'Politics: Mentions the process of making decisions and policies in a society.', 'subtopics': ['Taxation: Mentions tax evasion and tax-exempt status.', "Slavery: Mentions the Bible's stance on slavery.", "COVID-19: Mentions the COVID-19 pandemic and its impact on society, including the actions of Christian extremists and Jehovah's Witnesses.", "Church of Scientology: Mentions the Church of Scientology's practices and allegations of abuse.", "Trump: Mentions Trump's presidency and his views on science.", "LGBT Rights: Mentions the LGBT community and their rights, with Document 14 criticizing a pastor's actions and Document 16 discussing Jehovah's Witnesses' anti-LGBT views.", "Religious Extremism: Mentions the actions of Christian extremists and Jehovah's Witnesses, with Document 14 criticizing a pastor's actions and Document 16 discussing Jehovah's Witnesses' cult-like behavior.", 'White Privilege: Mentions white privilege and racism.', 'Human Rights: Mentions human rights and the Universal Declaration of Human Rights.', 'Democratic Debate: Mentions a Democratic debate.']}
# Period before
# Ideology:  ANTI_THEIST
# Topics:  {'main_topic': 'Politics: Mentions the topic of politics and the election of Donald Trump.', 'subtopics': ['Church-State Separation: Discusses the erosion of the separation between church and state in the US, its implications, and the importance of maintaining this separation.']}
# Period after
# Ideology:  BLACK
# Topics:  {'main_topic': 'Politics: Mentions the importance of being aware of and involved in politics, particularly in relation to Israelites.', 'subtopics': ['Public Policy and Governance: Mentions public policy, governance, and decision-making.', 'Personal Freedom and Autonomy: Mentions personal freedom, autonomy, and self-expression.', 'Social Responsibility and Accountability: Mentions social responsibility, accountability, and justice.', 'Social Norms and Values: Mentions social norms, values, and cultural expectations.', 'Social Justice and Human Rights: Mentions social justice, human rights, and dignity.', 'Community Engagement and Participation: Mentions community engagement, participation, and empowerment.', 'Social Change and Revolution: Mentions social change, revolution, and activism.', 'Community Development and Growth: Mentions community development, growth, and empowerment.', 'Community Building and Growth: Mentions community building, growth, and empowerment.', 'Community Empowerment and Growth: Mentions community empowerment, growth, and self-determination.']}
# Period before
# Ideology:  BLACK
# Topics:  {'main_topic': "Politics: Implied through the discussion of Trump's views and his meeting with Russian billionaires.", 'subtopics': ['Racism: Mentions the system of white supremacy and its effects on Black people, including economic, educational, and social issues.', 'Social Inequality: Mentions the historical and ongoing struggles of Black people in the United States, including lack of access to education, resources, and opportunities.']}
# Period after
# Ideology:  CONSPIRACY
# Topics:  {'main_topic': 'Politics: Mentions policies, politicians, and governance.', 'subtopics': ['Freemasonry and Secret Societies: Mentions the influence of secret societies and occult groups on world events.', 'Prophecy and End Times: Mentions the fulfillment of prophecy and the end times.', "Patriotism and Nationalism: Mentions the importance of patriotism and the American people's discipline.", 'Civil Unrest: Mentions the possibility of a civil war in the United States.', 'Presidential Scandals: Mentions the scandals surrounding Joe Biden and Hunter Biden.', 'Government Corruption: Mentions the possibility of a shadow government and voter fraud.', 'Military and Veterans: Mentions the respect for American service members and the challenges of a civil war.', 'Racial Identity: Mentions the concept of Melangeans and racial identity.', 'Natural Disasters: Mentions the devastating impact of floods on China and the world.', 'Food Shortage: Mentions the potential for a massive famine or food shortage due to the floods.']}
# Period before
# Ideology:  CONSPIRACY
# Topics:  {'main_topic': "Politics: Mentions the speaker's involvement in politics, including events like Davos and the World Bank.", 'subtopics': ['Economic Inequality: Discusses the issue of economic inequality and its potential connections to broader social and economic issues.', 'Economic Stability: Discusses the issue of economic stability and its potential connections to broader social and economic issues.', 'Economic Security: Mentions the issue of economic security and its potential connections to broader social and economic issues.', 'Economic Freedom: Discusses the issue of economic freedom and its potential connections to broader social and economic issues.', 'Economic Liberty: Mentions the issue of economic liberty and its potential connections to broader social and economic issues.', 'Economic Justice: Discusses the issue of economic justice and its potential connections to broader social and economic issues.', 'Economic Equality: Mentions the issue of economic equality and its potential connections to broader social and economic issues.', 'Economic Mobility: Mentions the issue of economic mobility and its potential connections to broader social and economic issues.', 'Economic Opportunity: Discusses the issue of economic opportunity and its potential connections to broader social and economic issues.', 'Economic Prosperity: Mentions the issue of economic prosperity and its potential connections to broader social and economic issues.']}
# Period after
# Ideology:  LGBT
# Topics:  {'main_topic': 'Politics: Mentions the rhetoric created by the gender-critical cult and the legislative violence threatened towards the trans community by Liz Truss.', 'subtopics': ['Trans Rights: Mentions the rights and issues faced by the trans community in the UK.']}
# Period before
# Ideology:  LGBT
# Topics:  {'main_topic': 'Politics: Mentions policies and goals related to government, legislation, and political action.', 'subtopics': ['Trans Rights: Discusses the rights and experiences of trans individuals.', 'Healthcare for Trans Individuals: Focuses on the challenges faced by trans individuals in accessing healthcare.', 'Science and Politics: Examines the intersection of science and politics, highlighting the influence of societal and cultural factors on scientific interpretation.', 'Disability Rights: Discusses the rights and needs of disabled individuals, particularly in relation to accessibility and medical equipment.', 'Environmentalism and Accessibility: Explores the balance between environmental concerns and accessibility needs, advocating for inclusive solutions.']}
# Period after
# Ideology:  LIBERTARIAN
# Topics:  {'main_topic': 'Politics: Mentions the influence of politicians and their policies on various issues.', 'subtopics': ['Economic Policy: Mentions the impact of economic policies on society.', 'Economic Growth: Mentions the impact of economic growth on society.', 'Productivity: Mentions the impact of productivity on the economy.', 'Investment: Mentions the impact of investment on the economy.', 'Skills: Mentions the impact of skills on the economy.', 'Taxation: Mentions the impact of taxation on society.', 'Deficits: Mentions the impact of deficits on the economy.', 'Debt: Mentions the impact of debt on the economy.', 'Spending: Mentions the impact of spending on the economy.', 'Fiscal Policy: Mentions the importance of fiscal policy.']}
# Period before
# Ideology:  LIBERTARIAN
# Topics:  {'main_topic': 'Politics: Mentions the actions and decisions of government officials and politicians.', 'subtopics': ['Public Administration Policy: Mentions the need for policy changes to simplify the land use process and reduce the impact of discretionary reviews.', 'Urban Renewal Policy: Mentions the need for policy changes to simplify the land use process and reduce the impact of discretionary reviews.', 'Economic Development Policy: Mentions the need for policy changes to simplify the land use process and reduce the impact of discretionary reviews.', "Public Finance Policy: Mentions the state's budget and the impact of high taxes on the middle class.", 'Urban Governance Policy: Mentions the need for policy changes to simplify the land use process and reduce the impact of discretionary reviews.', 'Military Strategy Policy: Mentions the poor performance of Arab militaries in major conflicts and the need for flexible command structures.', 'International Relations Policy: Mentions the idea of returning to sovereign nation-states and the global economy.', 'Government Accountability Policy: Mentions the polarization of the parties and the renationalization of American elections.', 'Censorship: Mentions restrictions on free speech and expression.', 'Diplomacy: Discusses the role of diplomats and international relations.']}
# Period after
# Ideology:  MRA
# Topics:  {'main_topic': 'Politics: Mentions the influence of politics on society and the role of politicians in shaping public opinion.', 'subtopics': ["Government Corruption: Discusses the Justin Trudeau government's scandals and corruption.", 'One World Government: Discusses the potential for a one world government and the role of the Vatican and Pope Francis.', 'Woke Culture: Discusses the controversy surrounding The Last of Us Part II and the impact of woke themes on the gaming industry.', "Government Overreach: Critiques the Australian government's handling of the COVID-19 pandemic and its economic costs.", 'Public Health: Discusses the spread of the coronavirus and the credibility of the World Health Organization.']}
# Period before
# Ideology:  MRA
# Topics:  {'main_topic': 'Politics: Mentions the intersection of politics and comedy, including the context of Tommy Robinson and Sargon of Akkad.', 'subtopics': ["Men's Issues: Mentions various issues affecting men, including homelessness, marriage, and mental health.", 'Feminism: Mentions the impact of feminism on modern society and relationships.', 'Masculinity: Mentions traditional and modern views of masculinity.', 'Marriage: Mentions the decline of marriage rates and the impact of feminism on modern relationships.', 'Victimhood: The idea that certain groups, such as men, are being unfairly targeted and victimized by others.', 'Homelessness: Mentions the issue of homelessness, particularly among men.', 'Pornography: Mentions the negative impact of pornography on individuals and society.', 'Totalitarianism: Mentions the concept of totalitarianism and its impact on modern society.', 'Incels: Mentions the concept of incels and the psychology behind their behavior.', 'Social Justice: The idea that society should be organized to promote fairness and equality for all individuals.']}
# Period after
# Ideology:  PARTISAN_RIGHT
# Topics:  {'main_topic': 'Politics: Mentions the actions and decisions of governments and leaders.', 'subtopics': ["CCP Virus: Discusses the ongoing outbreak in China and the Chinese Communist Party's response to it.", "Trade: Mentions the UK's trade policies and its relationship with the EU.", 'Election Interference: Discusses a tabulating software glitch that caused a 6,000 vote swing against Republican candidates in Antrim County, Michigan.', 'Election 2020: Discusses various aspects of the 2020 US presidential election.', 'Racial Tensions: Discusses the opinions of Biden-supporting Democrats on various quotes attributed to President Trump and Joe Biden.', 'Voter Disenfranchisement: Mentions concerns about potential discrepancies in election results due to the use of the same software in 47 counties.', "Brexit: Discusses the UK's withdrawal from the EU and its implications.", 'Election Disputes: Mentions disputes over the outcome of the 2020 US presidential election.', "Law and Order: Discusses the Biden campaign's stance on law and order and its implications.", 'Police Reform: Mentions the proposal to redirect funds away from the police and close the King County Jail in Seattle.']}
# Period before
# Ideology:  PARTISAN_RIGHT
# Topics:  {'main_topic': 'Politics: Mentions government policies, laws, and governance.', 'subtopics': ["Brexit Party's Impact on the Global Economy: Discusses the implications of the party's impact on the global economy for the European elections and the potential impact on global politics.", "Brexit Party's Impact on the Global Market: Discusses the implications of the party's impact on the global market for the European elections and the potential impact on global politics.", "Brexit Party's Impact on the Global Trade: Discusses the implications of the party's impact on the global trade for the European elections and the potential impact on global politics.", "Brexit Party's Impact on the Global Politics: Discusses the implications of the party's impact on the global politics for the European elections and the potential impact on global politics.", 'Social Justice: Mentions the debate on social justice and the importance of inclusivity and equality.', 'Impeachment: Discusses the implications of the impeachment inquiry against President Trump.', 'Free Speech: Discusses the importance of free speech and the impact of protests on the right to free speech.', 'Brexit: Discusses the potential impact of the European elections on Brexit.', 'Gun Control: The governor of Wisconsin, Tony Evers, is considering a mandatory buyback of AR-15s in the state.', 'Trade: Mentions export policies on goods and the impact of laws on trade.']}
# Period after
# Ideology:  PARTISAN_LEFT
# Topics:  {'main_topic': 'Politics: Mentions policies and governance.', 'subtopics': ['Public Opinion: Mentions public perception, opinions, and reactions to government and election-related issues.', 'Policy: Mentions the actions, decisions, and regulations made by the government.', 'Trumpism: Mentions the ideology, policies, and actions associated with the presidency of Donald Trump.', 'Government: Mentions government policies, officials, and actions.', 'Activism: Mentions the actions and efforts of individuals or groups to bring about social or political change.', 'Science: Mentions the application of scientific knowledge and methods to understand and address social and political issues.', "Patriotism: Mentions the love, loyalty, and devotion to one's country.", 'Nationalism: Mentions the promotion of national identity, interests, and values.', 'Law and Justice: Mentions the legal system, laws, and justice in a country or region.', 'Media and Propaganda: Mentions the role of media and propaganda in shaping public opinion and influencing government policies.']}
# Period before
# Ideology:  PARTISAN_LEFT
# Topics:  {'main_topic': 'Politics: Mentions policies, governance, and the actions of politicians.', 'subtopics': ["Donald Trump: Mentions the president's actions and policies.", 'Republican Party: Mentions the Republican Party and its policies.', 'US Foreign Policy: The US attempting a coup in Venezuela under the guise of humanitarian aid and its potential consequences.', 'Democratic Party: Mentions the Democratic Party and its primaries.', 'Progressive Politics: Mentions progressive policies and candidates.', 'International Relations: The G7 meeting in Biarritz and its exclusion of major players like China and Russia.', "US Economy: Mentions the country's economic policies and the impact of trade wars.", "Banking and Finance: The investigation into Trump's business ties with Deutsche Bank and the suspicious death of Thomas Bowers.", 'US Politics: Mentions the current state of politics in the US.', "Presidential Elections: Recent polls showing Bernie Sanders' chances of winning the nomination."]}
# Period after
# Ideology:  QANON
# Topics:  {'main_topic': 'Politics: Mentions government, elections, and political actions.', 'subtopics': ['International Relations: Mentions international relations and conflicts.', 'Foreign Policy: Mentions international relations and policies.', 'Media: Discusses the role and impact of the media on society.', 'Presidential Actions: Mentions actions taken by the President.', 'Media Bias: Mentions media bias and manipulation.', 'Scandals: Mentions scandals and controversies surrounding public figures.', 'Elections: Mentions election processes and fraud.', 'Government Corruption: Mentions corruption within the government.', 'Congressional Actions: Mentions actions taken by Congress.', 'Law Enforcement: Mentions law enforcement actions and cover-ups.']}
# Period before
# Ideology:  QANON
# Topics:  {'main_topic': 'Politics: Mentions the promotion of a political agenda, including the phrase "Make America great again."', 'subtopics': ['Industrial Shortage: Mentions the industrial shortage of silver in Mexico, Peru, and Chile.', 'Russia: Mentions the potential impact of Russia on the price of gold and silver.', 'Mexico: Mentions the industrial shortage of silver in Mexico.', 'Peru: Mentions the industrial shortage of silver in Peru.', 'Chile: Mentions the industrial shortage of silver in Chile.', 'JP Morgan: Mentions the role of JP Morgan in the economy.', 'Goldman Sachs: Mentions the role of Goldman Sachs in the economy.', 'Derivative Machinery: Mentions the role of derivative machinery in the economy.', 'Short Positions: Mentions the short positions of banks in gold and silver.', 'Simulation Results: Mentions the quality of simulation results in the economy.']}
# Period after
# Ideology:  RELIGIOUS_CONSERVATIVE
# Topics:  {'main_topic': 'Politics: Mentions policies and actions of government officials.', 'subtopics': ['Government Corruption: Mentions allegations of corruption in government, including the removal of a judge and the potential for corruption in the Democratic hierarchy.', 'Policy Differences: Mentions the differences in policies between California and Texas, as well as the contrast between red and blue states in the US.', 'International Relations: Mentions the peace deal between Israel and Morocco, as well as concerns about the transfer of power from Congress to transnational regional bodies.', 'Environmentalism: Mentions the potential harm caused by transitioning to wind and solar energy, including the killing of birds and bats and the destruction of wildlife habitats.', 'Faith and Politics: Mentions the intersection of faith and politics in the context of prayer, prophecy, and the role of the Catholic Church.', "Public Health Policy: Discusses the effectiveness of Sweden's approach to handling the COVID-19 pandemic and compares it to other Western countries."]}
# Period before
# Ideology:  RELIGIOUS_CONSERVATIVE
# Topics:  {'main_topic': "Politics: Mentions the intersection of politics and religion, particularly in the context of the Pope's statements.", 'subtopics': ['Faith and Politics: Examines the complex relationship between faith and politics, including the potential implications for individual and collective values, policies, and actions.', 'Christianity: Discusses the role of Christianity in society and its relationship with other faiths.', 'Government Accountability: Analyzes the concept of government accountability, including its potential causes, consequences, and implications for individual and collective freedoms.', 'Global Peace: Examines the concept of global peace, including its potential causes, consequences, and implications for individual and collective values, politics, and culture.', 'Global Governance: Examines the concept of global governance and its implications for national sovereignty.', 'International Relations: Discusses the complexities and challenges of global diplomacy, including trade tensions and international agreements.', 'American History: Explores the history of the United States, including its founding, its relationship with other countries, and its cultural heritage.', 'Globalism: Discusses the concept of globalism and its implications for national sovereignty and economic systems.', 'Christian Faith: Discusses the principles and implications of Christian faith, including its potential impact on individual and collective values, politics, and culture.', 'Biblical Prophecy: Examines the concept of biblical prophecy, including its potential causes, consequences, and implications for individual and collective values, politics, and culture.']}
# Period after
# Ideology:  SOCIAL_JUSTICE
# Topics:  {'main_topic': 'Politics: Mentions policies, governance, and the actions of government officials.', 'subtopics': ['Police and Authoritarianism: Mentions the rise of authoritarianism and its impact on police and the need for police reform.', 'Police and Community: Mentions the need for police reform and the importance of building trust between law enforcement and the communities they serve.', 'Police and Racism: Mentions the issue of police racism and the need for police reform to address this issue.', 'Police and Inequality: Mentions the issue of police inequality and the need for police reform to address this issue.', 'Police Reform: Mentions the need for police reform and the importance of addressing systemic issues such as racism and inequality.', 'Police and Defunding the Police: Mentions the concept of defunding the police and the need for clear communication and education to ensure that the public understands the goals and implications of this policy.', 'Social Issues: Mentions abortion, COVID-19, and systemic racism in law enforcement.', 'Democracy: Mentions the importance of democracy, the role of pollsters, and the threat to democracy posed by a group.', 'Elections: Mentions the selection of a running mate, the presidential campaign, and the results of the election.', 'Authoritarianism and Democracy: Mentions the tension between authoritarianism and democracy in politics.']}
# Period before
# Ideology:  SOCIAL_JUSTICE
# Topics:  {'main_topic': 'Politics: Mentions policies, governance, and the actions of politicians.', 'subtopics': ["Social Justice: Refers to the promotion of social justice and equality, as discussed in the context of Senator Harris's discussion of race, the Medicare for All plan, and Greta Thunberg's advocacy.", "Corruption: Mentions discrepancies in tax documents and conflicting information about a building's occupancy rate, suggesting corruption in the Trump administration.", 'Climate Change: Mentions the urgent need for collective action to address climate change and the importance of unity in the face of this crisis.', 'Nationalism: Mentions the rise of nationalism in Canada and its impact on society, including the erosion of a welcoming country for people from different backgrounds.', "Impeachment: Mentions the impeachment inquiry into President Donald Trump and the speaker's argument that Trump's conduct was unethical.", "Brexit: Mentions the UK's perspective on Brexit and the EU, including the country's history and its views on the EU's political aims.", "US Politics: Refers to the politics and government of the United States, as discussed in the context of Elizabeth Warren's presidential campaign, the arrest of Julian Assange, and the CFPB's enforcement actions.", 'Authoritarianism: The House Judiciary Committee heard testimony from former White House Counsel John Dean, who spoke about the authoritarian tendencies of the Republican Party.', "Democracy: Refers to the system of government in which power is held by the people or their elected representatives, as discussed in the context of the US's actions and Greta Thunberg's advocacy.", 'Human Rights: Refers to the fundamental rights and freedoms that are inherent to all human beings, as discussed in the context of healthcare and climate change.']}
# Period after
# Ideology:  SOCIALIST
# Topics:  {'main_topic': 'Politics: Mentions the governance and administration of a country or organization.', 'subtopics': ['Media Criticism: Criticizes the corporate media for promoting fear and hatred.', 'Economic Policy: Mentions a new stimulus package and its proposals.', 'Socialism: Explores the principles and practices of socialism, including its application in different contexts.', 'Healthcare: Discusses the impact of COVID-19 on the National Health Service.', 'Foreign Policy: Examines the relationships between countries and the actions of governments in international relations.', "Trump Supporters: Mentions Trump supporters' views and feelings about the media and the country's issues.", "Never-Trumpers: Mentions the influence of the Lincoln Project on the Democratic Party's agenda.", "Biden's Leadership: Mentions Biden's ads against Trump and his leadership abilities.", "Biden's Behavior: Mentions Biden's behavior and his response to criticisms from black civil rights leaders.", "Bernie Sanders: Mentions Bernie Sanders' leadership and his efforts to raise funds for coronavirus relief efforts."]}
# Period before
# Ideology:  SOCIALIST
# Topics:  {'main_topic': 'Politics: Mentions the system of government, governance, and the distribution of power.', 'subtopics': ['Politics and Society: Mentions the relationship between politics and society.', 'Politics and War: Discusses the relationship between politics and war.', 'Politics and Media: Mentions the relationship between politics and media.', 'Politics and History: Mentions the relationship between politics and history.', 'Politics and Culture: Discusses the relationship between politics and culture.', 'Politics and Environment: Examines the relationship between politics and the environment.', 'Social Movements: Mentions various social movements and their impact on society.', 'Imperialism: Mentions the US history of invading and overthrowing democratically elected governments.', 'Nationalism: Discusses the concept of nationalism and its different forms.', 'History: Examines the oldest political parties to exist and their legacies.']}
# Period after
# Ideology:  WHITE_IDENTITARIAN
# Topics:  {'main_topic': 'Politics: Mentions the system of government and the process of making decisions that affect a community.', 'subtopics': ['Healthcare Workers: Mentions the behavior and impact of healthcare workers on society.', 'Election: Mentions the general election in Slovakia and the results of the election.', "Identity: Mentions the YouTuber's views on Nick Fuentes and their own identity as a gay man.", "Influence: Mentions Jared Kushner's influence on President Donald Trump's agenda.", 'Fair Pricing: Mentions the need for fair pricing legislation to ensure farmers receive a fair share of the final retail price of food.', "National Identity: Mentions the speaker's concerns about the European Union's policies and the perceived loss of Irish identity.", "Ministerial Appointment: Mentions the controversy surrounding Minister Roderick O'Gorman's association with Peter Tatchell.", "Leadership: Mentions the speaker's desire to elevate their country and their gratitude to the audience.", 'Government: Mentions the new prime minister of Slovenia, Janez Janša, and the shift from center-left to center-right.', 'Border Control: Mentions the situation at the Turkey-Greece border and the actions of the Turkish government.']}
# Period before
# Ideology:  WHITE_IDENTITARIAN
# Topics:  {'main_topic': 'Politics: Mentions the actions and decisions of government officials and the process of governance.', 'subtopics': ['Censorship in Writing: Mentions the increasing politicization and restriction of the writing industry, particularly the young adult branch.', "Immigration Policy: Mentions Poland's decision not to accept any refugees, particularly Muslims.", "White Advocacy: Mentions Jared Taylor's advocacy for white interests and racial realism.", "Justin Trudeau's Visit: Mentions the controversy surrounding Justin Trudeau's visit to Constance Bay.", 'Human Trafficking: Mentions the investigation of human trafficking in Morocco.', 'Labor Unions: Mentions the IG Metal and YouTubers Union joining forces to fight for the rights of YouTubers.', 'Italian Elections: Mentions the regional elections in Calabria and Emilia-Romagna.', 'Academic Freedom: Mentions the lack of representation of right-wing ideas in university classrooms.', 'Hate Crimes: Mentions the increasing violence and racism in the Western world, particularly against white people.', 'Green New Deal: Mentions the Green New Deal as a pretext for increasing global socialist control.']}
# /ceph/iharsawi/miniconda3/envs/thesis7/lib/python3.10/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# Cosine Similarity between Ideologies Before and After COVID (Politics only):
# ANTI_SJW: 0.9996
# ANTI_THEIST: 0.9989
# BLACK: 0.9590
# CONSPIRACY: 0.9762
# LGBT: 1.0000
# LIBERTARIAN: 0.9818
# MRA: 0.9835
# PARTISAN_LEFT: 0.9937
# PARTISAN_RIGHT: 0.9997
# QANON: 0.9756
# RELIGIOUS_CONSERVATIVE: 0.9991
# SOCIALIST: 0.9953
# SOCIAL_JUSTICE: 1.0000
# WHITE_IDENTITARIAN: 0.9986
